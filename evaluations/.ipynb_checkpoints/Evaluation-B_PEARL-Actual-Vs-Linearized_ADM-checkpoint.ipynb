# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
from z3 import *
from itertools import combinations
import itertools
import matplotlib.pyplot as plt
import os
import json
import sys
sys.path.append("../scripts/")
from ControlCost import *
from ActualADM import *
from AttackCost import *
from LinearizedADM import *
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Current and parent directories

# %%
current_directory = os.getcwd()
parent_directory = os.path.dirname(current_directory)

# %% [markdown]
# # Accessing Zone-Activity-Appliances Information

# %%
zones = pd.read_excel(str(parent_directory) + '/data/Aras-Information.xlsx', sheet_name='Zone-Info')
zone_volume = zones["Volume (cf)"].to_list()                  # Zones' volumes (cubic feet)

energy_appliances = pd.read_excel(str(parent_directory) + '/data/Aras-Information.xlsx', sheet_name='Appliances-Info').iloc[:,-1].to_numpy()
benign_activity_appliances_map = pd.read_excel(str(parent_directory) + '/data/Aras-Information.xlsx', sheet_name='Benign-Activity-Appliances-Map').iloc[:, 4:].to_numpy()

pp_co2 = zones["CO2 Emission by Occupant (cfm)"].to_list()    # CO2 Emission by Occupant (cfm)
pp_heat = zones["Heat Radiation by Occupant (W)"].to_list()   # Heat Radiation by Occupant (W)
load = zones["Heat Radiated by Appliances (W)"].to_list()     # Heat radiated by Appliances (W)

num_zones = len(zones)
num_timeslots = 1440

activities = pd.read_excel(str(parent_directory) + '/data/Aras-Information.xlsx', sheet_name='Activity-Info')
num_activities = len(activities)
activity_zone_map = dict()
for i in range(len(activities)):
    activity_zone_map[int(activities["Activity ID"][i])] = int(activities["Zone ID"][i])

activity_zone_temp_setpoint = [0]
activity_zone_co2_setpoint = [0] 
activity_pp_co2 = [0] + activities['CO2 Emission by Occupant (CFM)'].to_list()    # CO2 Emission by Occupant (cfm)
activity_pp_heat = [0] + activities["Heat Radiation by Occupant (W)"].to_list()   # Heat Radiation by Occupant (W)
activity_load = [0]# Heat radiated by Appliances (W)
activity_zone_volume = [0]

for i in range(1, num_activities + 1):
    activity_zone_temp_setpoint.append(zone_temp_setpoint[activity_zone_map[i]])
    activity_zone_co2_setpoint.append(zone_co2_setpoint[activity_zone_map[i]])
    activity_zone_volume.append(zone_volume[activity_zone_map[i]])
    activity_load.append(sum(benign_activity_appliances_map[i] * energy_appliances))
    
all_samples = list(itertools.permutations([1, 1, 0, 0, 0]))
all_samples += list(itertools.permutations([2, 0, 0, 0, 0]))

unique_samples = set()

for data in all_samples:    
    unique_samples.add(data)

# %% [markdown]
# # Convert list to a tuple

# %%
def to_tuple(a):
    try:
        return tuple(to_tuple(i) for i in a)
    except TypeError:
        return a

# %% [markdown]
# # Fixed parameters

# %%
CO2_FRESH_AIR = 400             # CO2 concentration (ppm) of fresh air
TEMP_FRESH_AIR = 91.4           # Temperature (33 degree F) of the fresh air
CP_AIR = 1.026                  # Specific heat of fresh air
DEF_TEMP_SUPPLY_AIR =  55.4     # Default temperature (degree fahrenheit) of supply air (13 degree celsius)

# %% [markdown]
# # Control cost calculation

# %%
def control_cost (zones, zone_occupant, zone_temp_setpoint, zone_volume, pp_co2, pp_heat, load, zone_co2_setpoint, control_time):
    '''
    PARAMETERS:
    zones: zone information
    zone_occupant: list of occupants in different zones
    zone_temp_setpoint: list of temperature (fahrenheit) setpoint of the different zones
    zone_volume: # Zones' volumes (cubic feet)
    pp_co2: CO2 Emission by Occupant (cfm)
    pp_heat: Heat Radiation by Occupant (W)
    load: Heat radiated by Appliances (W)
    zone_co2_setpoint: list of CO2 (ppm) setpoint of the corresponding zones
    control_time: time of control operation (in minute)
    energy_cost: cost per KWh (USD) at the control time
    '''
    num_zones = len(zones)
    # initializing z3 variables
    v_vent_air = [Real( 'v_vent_air_' + str(i)) for i in range(num_zones)]   # Air required for ventillation (CFM)
    v_temp_air = [Real( 'v_temp_air_' + str(i)) for i in range(num_zones)]   # Air required for cooling (CFM)
    v_mixed_air = [Real( 'v_mixed_air_' + str(i)) for i in range(num_zones)]
    v_fresh_air = [Real( 'v_fresh_air_' + str(i)) for i in range(num_zones)]
    v_return_air = [Real( 'v_return_air_' + str(i)) for i in range(num_zones)]
    zone_cost = [Real( 'zone_cost' + str(i)) for i in range(num_zones)] 
    
    temp_supply_air = [ Real( 'temp_supply_air_' + str(i)) for i in range(num_zones)]
    temp_mixed_air = [ Real( 'temp_mixed_air_' + str(i)) for i in range(num_zones)]
    co2_mixed_air = [ Real( 'co2_mixed_air_' + str(i)) for i in range(num_zones)]
    total_zone_cost = Real('total_zone_cost')

    s = Solver()
    
    for i in range(1, num_zones):
        ############### v_vent_air ###############################
        s.add(zone_occupant[i] * ((pp_co2[i] * 1000000) / zone_volume[i]) == 
                       (zone_co2_setpoint[i] - (( 1 - (v_vent_air[i]) /zone_volume[i]) * zone_co2_setpoint[i] +  
                                                (v_vent_air[i] * CO2_FRESH_AIR) /  zone_volume[i])))
        
        ############### v_temp_air ###############################
        if zone_occupant[i] > 0:
            s.add(v_temp_air[i] *  (zone_temp_setpoint[i] - DEF_TEMP_SUPPLY_AIR) * 0.3167 == zone_occupant[i] * pp_heat[i] + load[i]) 
        else:
            s.add(v_temp_air[i] *  (zone_temp_setpoint[i] - DEF_TEMP_SUPPLY_AIR) * 0.3167 == zone_occupant[i] * pp_heat[i]) 
    
        ############### v_mixed_air ###############################
        s.add(zone_occupant[i] * ((pp_co2[i] * 1000000) / zone_volume[i]) == 
              (zone_co2_setpoint[i] - (( 1 - ( v_mixed_air[i] ) / zone_volume[i]) * zone_co2_setpoint[i] + 
                                     ( v_mixed_air[i] * co2_mixed_air[i]) / zone_volume[i])))
    
        if zone_occupant[i] > 0:
            s.add(v_mixed_air[i] * (zone_temp_setpoint[i] - temp_supply_air[i]) * 0.3167 == zone_occupant[i] * pp_heat[i] + load[i])
        else:
            s.add(v_mixed_air[i] * (zone_temp_setpoint[i] - temp_supply_air[i]) * 0.3167 == zone_occupant[i] * pp_heat[i])

        s.add(v_mixed_air[i] == v_return_air[i] + v_fresh_air[i])
        s.add(co2_mixed_air[i] == zone_co2_setpoint[i] * (v_return_air[i] / v_mixed_air[i]) + CO2_FRESH_AIR * (v_fresh_air[i] / v_mixed_air[i]))
        s.add(temp_mixed_air[i] == zone_temp_setpoint[i] * (v_return_air[i] / v_mixed_air[i]) + TEMP_FRESH_AIR * (v_fresh_air[i] / v_mixed_air[i]))
    
        ############### temperature control algorithm ############
        s.add(Implies(v_vent_air[i] >= v_temp_air[i] , v_return_air[i] == 0))
        s.add(Implies(v_vent_air[i] < v_temp_air[i] ,  temp_supply_air[i] == 55.4))
    
        ############### other constraints ########################
        s.add(v_return_air[i] >= 0)
        s.add(temp_supply_air[i] >= 55.4)
        
        ############## cost constraint ###########################
        s.add(zone_cost[i] == v_mixed_air[i] * (temp_mixed_air[i] - DEF_TEMP_SUPPLY_AIR) * 0.3167 * (control_time / 60000))
    s.add(total_zone_cost == Sum(zone_cost[1:]))
    s.check()
    
    for i in range(1, num_zones):
        v_vent_air[i] = float(Fraction(str(s.model()[v_vent_air[i]])))
        v_temp_air[i] = float(Fraction(str(s.model()[v_temp_air[i]])))
    
        v_mixed_air[i] = float(Fraction(str(s.model()[v_mixed_air[i]])))
        temp_mixed_air[i] = float(Fraction(str(s.model()[temp_mixed_air[i]])))
    
        temp_supply_air[i] = float(Fraction(str(s.model()[temp_supply_air[i]])))
    
        co2_mixed_air[i] = float(Fraction(str(s.model()[co2_mixed_air[i]])))
        v_return_air[i] = float(Fraction(str(s.model()[v_return_air[i]])))
        v_fresh_air[i] = float(Fraction(str(s.model()[v_fresh_air[i]])))
        
        zone_cost[i] = float(Fraction(str(s.model()[zone_cost[i]])))
    total_zone_cost = float(Fraction(str(s.model()[total_zone_cost])))
        
    return total_zone_cost

dict_control_cost = dict()
for sample in unique_samples:
    zone_occupant = list(sample)    
    dict_control_cost[sample] = control_cost(zones, zone_occupant, zone_temp_setpoint, zone_volume, pp_co2, pp_heat, load, zone_co2_setpoint, control_time)

# %% [markdown]
# # Zone-wise appliances

# %%
zone_appliance = []
zone_appliance.append([1, 2]) #0
zone_appliance.append([11, 16, 17, 23, 27]) #1
zone_appliance.append([12, 13, 18, 22, 25, 26]) #2
zone_appliance.append([3, 4, 5, 6, 7, 8, 9, 10, 19, 24]) #3
zone_appliance.append([14, 15, 20, 21]) #4

# %% [markdown]
# # Zone-wise maximum cost for appliances

# %%
zone_cost = [0, 0, 0, 0, 0]
for i in range(len(zone_cost)):
    all_costs = []
    for j in range(len(zone_appliance[i])):
        all_costs.append(activity_load[zone_appliance[i][j]])
    zone_cost[i] =  max(all_costs)

# %% [markdown]
# # Tabulating Cost for a house A and B (Actual ADM)

# %%
actual_adm = pd.DataFrame()

house_names = []
adm_algos = []
knowledges = []
costs = []
for house_name in ['A', 'B']:
    for adm_algo in ["DBSCAN", "K-Means"]:
        for knowledge in ["Full", "Partial"]:  
            print(house_name, adm_algo, knowledge)
            control_costs = pd.read_csv(str(parent_directory) + '\data\\control-costs\\Control-Costs_House-' +str(house_name) +'.csv')['Control Cost ($)'] 
            day_wise_control_costs = []
            for i in range(0, 43200, 1440):
                day_wise_control_costs.append(sum(control_costs[i:i+1400]))

            filename = str(parent_directory) + '\data\\Pearl-Attack-Costs_Actual' + '.json'
            with open(filename, 'r') as file:
                data = json.load(file)

            cost_occ_1 = data[str(adm_algo) + '-' + str(knowledge) + '_House-' + str(house_name) + '_Occupant-1']
            index_of_max_occ_1 = max(enumerate(cost_occ_1), key=lambda x: x[1])[0]

            cost_occ_2 = data[str(adm_algo) + '-' + str(knowledge) + '_House-' + str(house_name) + '_Occupant-2']
            index_of_max_occ_2 = max(enumerate(cost_occ_2), key=lambda x: x[1])[0]

            attack_schedule_1_file = str(parent_directory) + '\data\\attack-schedules\\pearl\\Actual_' + str(adm_algo) + '-' + str(knowledge) + '_House-' + str(house_name) + '_Occupant-1_Episode-' + str(index_of_max_occ_1) + '.json'
            attack_schedule_2_file = str(parent_directory) + '\data\\attack-schedules\\pearl\\Actual_' + str(adm_algo) + '-' + str(knowledge) + '_House-' + str(house_name) + '_Occupant-2_Episode-' + str(index_of_max_occ_2) + '.json'

            with open(attack_schedule_1_file, 'r') as file:
                attack_schedule_1 = json.load(file)

            with open(attack_schedule_2_file, 'r') as file:
                attack_schedule_2 = json.load(file)

            dataframe = pd.read_csv(str(parent_directory) + '\data\\modified\\' + 'Modified-Dataframe_House-' + str(house_name) + '.csv')
            cleaned_dataframe_occ_1 = pd.read_csv(str(parent_directory) + '\data\\cleaned\\' + 'Cleaned-Dataframe_House-' + str(house_name) + '_Occupant-1' + '.csv')
            cleaned_dataframe_occ_2 = pd.read_csv(str(parent_directory) + '\data\\cleaned\\' + 'Cleaned-Dataframe_House-' + str(house_name) + '_Occupant-2' + '.csv')

            processed_dataframe = pd.read_csv(str(parent_directory) + '\data\\processed\\' + 'Processed-Dataframe_House-' + str(house_name) + '.csv')

            actual_adm_occ_1 = ActualADM(adm_algo, cleaned_dataframe_occ_1, knowledge, house_name, '1', num_timeslots, num_zones)
            list_time_min_occ_1, list_time_max_occ_1 = actual_adm_occ_1.noise_augmented_range_calculation()

            actual_adm_occ_2 = ActualADM(adm_algo, cleaned_dataframe_occ_2, knowledge, house_name, '2', num_timeslots, num_zones)
            list_time_min_occ_2, list_time_max_occ_2 = actual_adm_occ_2.noise_augmented_range_calculation()

            without_appliances_attack_costs = AttackCost(house_name, dataframe, cleaned_dataframe_occ_1, cleaned_dataframe_occ_2, processed_dataframe, list_time_min_occ_1, list_time_max_occ_1, list_time_min_occ_2, list_time_max_occ_2, attack_schedule_1, attack_schedule_2, dict_control_cost, num_timeslots, num_zones, activity_zone_map, zone_cost).get_attack_costs_without_appliance_triggering()
            with_appliances_attack_costs = AttackCost(house_name, dataframe, cleaned_dataframe_occ_1, cleaned_dataframe_occ_2, processed_dataframe, list_time_min_occ_1, list_time_max_occ_1, list_time_min_occ_2, list_time_max_occ_2, attack_schedule_1, attack_schedule_2, dict_control_cost, num_timeslots, num_zones, activity_zone_map, zone_cost).get_attack_costs_with_appliance_triggering().tolist()
            
            house_names.append(house_name)
            adm_algos.append(adm_algo)
            knowledges.append(knowledge)
            costs.append(sum([a + b for a, b in zip(without_appliances_attack_costs, with_appliances_attack_costs)]))

actual_adm["Houses"] = house_names        
actual_adm["ADM Algos"] = adm_algos        
actual_adm["Knowledges"] = knowledges        
actual_adm["Costs"] = costs
# Out:
# A DBSCAN Full
# A DBSCAN Partial
# A K-Means Full
# A K-Means Partial
# B DBSCAN Full
# B DBSCAN Partial
# B K-Means Full
# B K-Means Partial

# %%
actual_adm
# Out:
#   Houses ADM Algos Knowledges       Costs
# 0      A    DBSCAN       Full  738.375813
# 1      A    DBSCAN    Partial  655.877913
# 2      A   K-Means       Full  864.513159
# 3      A   K-Means    Partial  667.384345
# 4      B    DBSCAN       Full  418.822604
# 5      B    DBSCAN    Partial  320.116832
# 6      B   K-Means       Full  453.148800
# 7      B   K-Means    Partial  361.363055

# %% [markdown]
# # Tabulating Cost for a house A and B (Linearized ADM)

# %%
linearized_adm = pd.DataFrame()

house_names = []
adm_algos = []
knowledges = []
costs = []
for house_name in ['A', 'B']:
    for adm_algo in ["DBSCAN", "K-Means"]:
        for knowledge in ["Full", "Partial"]:  
            print(house_name, adm_algo, knowledge)
            control_costs = pd.read_csv(str(parent_directory) + '\data\\control-costs\\Control-Costs_House-' +str(house_name) +'.csv')['Control Cost ($)'] 
            day_wise_control_costs = []
            for i in range(0, 43200, 1440):
                day_wise_control_costs.append(sum(control_costs[i:i+1400]))

            filename = str(parent_directory) + '\data\\Pearl-Attack-Costs_Linearized' + '.json'
            with open(filename, 'r') as file:
                data = json.load(file)

            cost_occ_1 = data[str(adm_algo) + '-' + str(knowledge) + '_House-' + str(house_name) + '_Occupant-1']
            index_of_max_occ_1 = max(enumerate(cost_occ_1), key=lambda x: x[1])[0]

            cost_occ_2 = data[str(adm_algo) + '-' + str(knowledge) + '_House-' + str(house_name) + '_Occupant-2']
            index_of_max_occ_2 = max(enumerate(cost_occ_2), key=lambda x: x[1])[0]

            attack_schedule_1_file = str(parent_directory) + '\data\\attack-schedules\\pearl\\Linearized_' + str(adm_algo) + '-' + str(knowledge) + '_House-' + str(house_name) + '_Occupant-1_Episode-' + str(index_of_max_occ_1) + '.json'
            attack_schedule_2_file = str(parent_directory) + '\data\\attack-schedules\\pearl\\Linearized_' + str(adm_algo) + '-' + str(knowledge) + '_House-' + str(house_name) + '_Occupant-2_Episode-' + str(index_of_max_occ_2) + '.json'

            with open(attack_schedule_1_file, 'r') as file:
                attack_schedule_1 = json.load(file)

            with open(attack_schedule_2_file, 'r') as file:
                attack_schedule_2 = json.load(file)

            dataframe = pd.read_csv(str(parent_directory) + '\data\\modified\\' + 'Modified-Dataframe_House-' + str(house_name) + '.csv')
            cleaned_dataframe_occ_1 = pd.read_csv(str(parent_directory) + '\data\\cleaned\\' + 'Cleaned-Dataframe_House-' + str(house_name) + '_Occupant-1' + '.csv')
            cleaned_dataframe_occ_2 = pd.read_csv(str(parent_directory) + '\data\\cleaned\\' + 'Cleaned-Dataframe_House-' + str(house_name) + '_Occupant-2' + '.csv')

            processed_dataframe = pd.read_csv(str(parent_directory) + '\data\\processed\\' + 'Processed-Dataframe_House-' + str(house_name) + '.csv')

            actual_adm_occ_1 = LinearizedADM(adm_algo, cleaned_dataframe_occ_1, knowledge, house_name, '1', num_timeslots, num_zones)
            list_time_min_occ_1, list_time_max_occ_1 = actual_adm_occ_1.noise_augmented_range_calculation()

            actual_adm_occ_2 = LinearizedADM(adm_algo, cleaned_dataframe_occ_2, knowledge, house_name, '2', num_timeslots, num_zones)
            list_time_min_occ_2, list_time_max_occ_2 = actual_adm_occ_2.noise_augmented_range_calculation()

            without_appliances_attack_costs = AttackCost(house_name, dataframe, cleaned_dataframe_occ_1, cleaned_dataframe_occ_2, processed_dataframe, list_time_min_occ_1, list_time_max_occ_1, list_time_min_occ_2, list_time_max_occ_2, attack_schedule_1, attack_schedule_2, dict_control_cost, num_timeslots, num_zones, activity_zone_map, zone_cost).get_attack_costs_without_appliance_triggering()
            with_appliances_attack_costs = AttackCost(house_name, dataframe, cleaned_dataframe_occ_1, cleaned_dataframe_occ_2, processed_dataframe, list_time_min_occ_1, list_time_max_occ_1, list_time_min_occ_2, list_time_max_occ_2, attack_schedule_1, attack_schedule_2, dict_control_cost, num_timeslots, num_zones, activity_zone_map, zone_cost).get_attack_costs_with_appliance_triggering().tolist()
            
            house_names.append(house_name)
            adm_algos.append(adm_algo)
            knowledges.append(knowledge)
            costs.append(sum([a + b for a, b in zip(without_appliances_attack_costs, with_appliances_attack_costs)]))

linearized_adm["Houses"] = house_names        
linearized_adm["ADM Algos"] = adm_algos        
linearized_adm["Knowledges"] = knowledges        
linearized_adm["Costs"] = costs
# Out:
# A DBSCAN Full
# A DBSCAN Partial
# A K-Means Full
# A K-Means Partial
# B DBSCAN Full
# B DBSCAN Partial
# B K-Means Full
# B K-Means Partial

# %%
linearized_adm
# Out:
#   Houses ADM Algos Knowledges       Costs
# 0      A    DBSCAN       Full  810.105282
# 1      A    DBSCAN    Partial  500.394475
# 2      A   K-Means       Full  767.696850
# 3      A   K-Means    Partial  671.236029
# 4      B    DBSCAN       Full  284.692281
# 5      B    DBSCAN    Partial  174.605445
# 6      B   K-Means       Full  365.111562
# 7      B   K-Means    Partial  424.253949

# %% [markdown]
# # SHATTER Attack Scheduling Function

# %%
def attack_scheduling(list_time_min, list_time_max, start_time, final_time):
    num_timeslots = interval = 10
    
    prev_stay = 1
    prev_schedule = -1
    ultimate_cost = 0
    final_schedule = schedule = np.zeros((final_time - start_time))

    for init_time in range(start_time, final_time, interval):
        cost = [Int( 'cost_' + str(i)) for i in range(NUM_ZONES)]
        zones = [Int( 'zones_' + str(i)) for i in range(NUM_ZONES)]

        schedule = [Int( 'schedule_' + str(i)) for i in range(init_time, init_time + interval)]
        stay = [Int( 'stay_' + str(i)) for i in range(num_timeslots)]
        slot_cost = [Int( 'slot_cost_' + str(i)) for i in range(num_timeslots)]

        total_cost = Int('total_cost')

        o = Optimize()
        o.add(cost[0] == 0)
        o.add(cost[1] == 1)
        o.add(cost[2] == 2)
        o.add(cost[3] == 4)
        o.add(cost[4] == 3)


        ############################################################################
        ################## schedule should be withing a valid zone #################
        ############################################################################
        for t in range(len(schedule)):
            or_constraints = []
            for z in range(NUM_ZONES):
                or_constraints.append(schedule[t] == z)
            o.add(Or(or_constraints))

        ###############################################################################################################
        ################## if zone stay threshdold in current time is 0, do not schedule to that zone #################
        ###############################################################################################################

        # base case
        for z in range(1, NUM_ZONES):
            if list_time_min[z][init_time] == [] or (len(list_time_max[z][init_time]) == 1 and list_time_max[z][init_time][0] == 0):
                o.add(Implies(schedule[0] != prev_schedule, schedule[t] != z))

        for t in range(1, len(schedule)):
            for z in range(1, NUM_ZONES):
                if list_time_min[z][init_time + t] == [] or (len(list_time_max[z][init_time + t]) == 1 and list_time_max[z][init_time + t][0] == 0):
                    o.add(Implies(schedule[t] != schedule[t - 1], schedule[t] != z))

        #######################################################################################################################
        ############################################ constraints of stay ######################################################
        #######################################################################################################################
        ######## base case for time 0 ############
        if init_time == 0:
            o.add(stay[0] == 1)
        else:
            o.add(Implies(schedule[0] == prev_schedule, stay[0] == prev_stay + 1))
            o.add(Implies(Not(schedule[0] == prev_schedule), stay[0] == 1))

        for t in range(1, len(schedule)):
            continue_staying = (schedule[t] == schedule[t - 1])
            increment_stay = (stay[t] == stay[t - 1] + 1)
            reset_stay = (stay[t] == 1)

            o.add(Implies(continue_staying, increment_stay))
            o.add(Implies(Not(continue_staying), reset_stay))

        #######################################################################################################################
        ############ move to a zone different that previous timeslot if stay > max threshold in previous timeslot #############
        #######################################################################################################################
        ######## base case for time 0 ############
        o.add(Implies(prev_stay == max(list_time_max[prev_schedule][init_time - prev_stay], default=0), schedule[0] != prev_schedule))

        for t in range(1, len(schedule)):
            max_stay_threshold = 0
            for z in range(1, NUM_ZONES):
                for p_t in range(1, init_time + len(schedule)):
                    continue_staying = (schedule[t] == schedule[t - 1])
                    o.add(Implies(And(schedule[t - 1] == z, stay[t - 1] == p_t, p_t == max(list_time_max[z][init_time + t - p_t], default=0)), Not(continue_staying)))

        #######################################################################################################################
        # must stay in the zone same as the previous timeslot if stay < max && stay is in previous timeslot is out of cluster #
        #######################################################################################################################
        ######## base case for time 0 ############
        ranges_stay_constraints = []
        for k in range(len(list_time_min[prev_schedule][init_time - prev_stay])):
            ranges_stay_constraints.append(And(prev_stay >= list_time_min[prev_schedule][init_time - prev_stay][k], prev_stay <= list_time_max[prev_schedule][init_time - prev_stay][k]))            

        if init_time != 0:
            o.add(Implies(Not(Or(ranges_stay_constraints)), schedule[0] == prev_schedule))

        for t in range(1, len(schedule)):
            for z in range(1, NUM_ZONES):
                for p_t in range(1, init_time + t + 1):
                    ranges_stay_constraints = []
                    for k in range(len(list_time_min[z][init_time + t - p_t])):
                        ranges_stay_constraints.append(And(p_t >= list_time_min[z][init_time + t - p_t][k], p_t <= list_time_max[z][init_time + t - p_t][k]))            

                    continue_staying = (schedule[t] == schedule[t - 1])
                    o.add(Implies(And(schedule[t - 1] == z, stay[t - 1] == p_t, Not(Or(ranges_stay_constraints))), continue_staying))

        for t in range(len(schedule)):
            for z in range(NUM_ZONES):
                o.add(Implies(schedule[t] == z, slot_cost[t] == cost[z]))

        o.add(total_cost == Sum(slot_cost))

        #o.add(schedule[0] == 3)

        o.maximize(total_cost)

        o.check()
        #print(init_time, o.model()[total_cost])
        ultimate_cost += int(str(o.model()[total_cost]))

        #print("Ulimate Cost", init_time, ultimate_cost)

        #print("Num_timeslot", num_timeslots, "Optimal_cost", o.model()[total_cost])

        for t in range(num_timeslots):
            #print("schedule_" + str(init_time + t), o.model()[schedule[t]])
            final_schedule[init_time + t] = int(str(o.model()[schedule[t]]))

        #for t in range(num_timeslots):
        #    print("stay_" + str(init_time + t), o.model()[stay[t]])

        prev_schedule = int(str(o.model()[schedule[-1]]))
        prev_stay = int(str(o.model()[stay[-1]]))
    return final_schedule

# %%
linearized_shchecker_adm = pd.DataFrame()

house_names = []
adm_algos = []
knowledges = []
costs = []

for house_name in ['A', 'B']:
    for adm_algo in ["DBSCAN", "K-Means"]:
        for knowledge in ["Full", "Partial"]:  
            print(house_name, adm_algo, knowledge)
            
            dataframe = pd.read_csv(str(parent_directory) + '\data\\modified\\' + 'Modified-Dataframe_House-' + str(house_name) + '.csv')
            
            cleaned_dataframe_occ_1 = pd.read_csv(str(parent_directory) + '\data\\cleaned\\' + 'Cleaned-Dataframe_House-' + str(house_name) + '_Occupant-1' + '.csv')
            cleaned_dataframe_occ_2 = pd.read_csv(str(parent_directory) + '\data\\cleaned\\' + 'Cleaned-Dataframe_House-' + str(house_name) + '_Occupant-2' + '.csv')

            processed_dataframe = pd.read_csv(str(parent_directory) + '\data\\processed\\' + 'Processed-Dataframe_House-' + str(house_name) + '.csv')

            actual_adm_occ_1 = LinearizedADM(adm_algo, cleaned_dataframe_occ_1, knowledge, house_name, '1', num_timeslots, num_zones)
            list_time_min_occ_1, list_time_max_occ_1 = actual_adm_occ_1.noise_augmented_range_calculation()

            actual_adm_occ_2 = LinearizedADM(adm_algo, cleaned_dataframe_occ_2, knowledge, house_name, '2', num_timeslots, num_zones)
            list_time_min_occ_2, list_time_max_occ_2 = actual_adm_occ_2.noise_augmented_range_calculation()
            
            attack_schedule_1 = attack_scheduling(list_time_min_occ_1, list_time_max_occ_1, 0, 1440)
            attack_schedule_2 = attack_scheduling(list_time_min_occ_2, list_time_max_occ_2, 0, 1440)
            
            attack_schedule_1 = attack_schedule_1.tolist()
            attack_schedule_2 = attack_schedule_2.tolist()
            attack_schedule_1 = [int(x) for x in attack_schedule_1]
            attack_schedule_2 = [int(x) for x in attack_schedule_2]

            
            without_appliances_attack_costs = AttackCost(house_name, dataframe, cleaned_dataframe_occ_1, cleaned_dataframe_occ_2, processed_dataframe, list_time_min_occ_1, list_time_max_occ_1, list_time_min_occ_2, list_time_max_occ_2, attack_schedule_1, attack_schedule_2, dict_control_cost, num_timeslots, num_zones, activity_zone_map, zone_cost).get_attack_costs_without_appliance_triggering()
            with_appliances_attack_costs = AttackCost(house_name, dataframe, cleaned_dataframe_occ_1, cleaned_dataframe_occ_2, processed_dataframe, list_time_min_occ_1, list_time_max_occ_1, list_time_min_occ_2, list_time_max_occ_2, attack_schedule_1, attack_schedule_2, dict_control_cost, num_timeslots, num_zones, activity_zone_map, zone_cost).get_attack_costs_with_appliance_triggering().tolist()
            
            house_names.append(house_name)
            adm_algos.append(adm_algo)
            knowledges.append(knowledge)
            costs.append(sum([a + b for a, b in zip(without_appliances_attack_costs, with_appliances_attack_costs)]))
            print(sum([a + b for a, b in zip(without_appliances_attack_costs, with_appliances_attack_costs)]))

linearized_shchecker_adm["Houses"] = house_names        
linearized_shchecker_adm["ADM Algos"] = adm_algos        
linearized_shchecker_adm["Knowledges"] = knowledges        
linearized_shchecker_adm["Costs"] = costs
# Out:
# A DBSCAN Full
# sat
# 0 40
# Ulimate Cost 0 40
# Num_timeslot 10 Optimal_cost 40
# schedule_0 3
# schedule_1 3
# schedule_2 3
# schedule_3 3
# schedule_4 3
# schedule_5 3
# schedule_6 3
# schedule_7 3
# schedule_8 3
# schedule_9 3
# stay_0 1
# stay_1 2
# stay_2 3
# stay_3 4
# stay_4 5
# stay_5 6
# stay_6 7
# stay_7 8
# stay_8 9
# stay_9 10
# sat
# 10 36
# Ulimate Cost 10 76
# Num_timeslot 10 Optimal_cost 36
# schedule_10 3
# schedule_11 3
# schedule_12 3
# schedule_13 3
# schedule_14 3
# schedule_15 3
# schedule_16 3
# schedule_17 3
# schedule_18 2
# schedule_19 2
# stay_10 11
# stay_11 12
# stay_12 13
# stay_13 14
# stay_14 15
# stay_15 16
# stay_16 17
# stay_17 18
# stay_18 1
# stay_19 2
# sat
# 20 20
# Ulimate Cost 20 96
# Num_timeslot 10 Optimal_cost 20
# schedule_20 2
# schedule_21 2
# schedule_22 2
# schedule_23 2
# schedule_24 2
# schedule_25 2
# schedule_26 2
# schedule_27 2
# schedule_28 2
# schedule_29 2
# stay_20 3
# stay_21 4
# stay_22 5
# stay_23 6
# stay_24 7
# stay_25 8
# stay_26 9
# stay_27 10
# stay_28 11
# stay_29 12
# sat
# 30 24
# Ulimate Cost 30 120
# Num_timeslot 10 Optimal_cost 24
# schedule_30 2
# schedule_31 2
# schedule_32 2
# schedule_33 2
# schedule_34 2
# schedule_35 2
# schedule_36 4
# schedule_37 4
# schedule_38 4
# schedule_39 4
# stay_30 13
# stay_31 14
# stay_32 15
# stay_33 16
# stay_34 17
# stay_35 18
# stay_36 1
# stay_37 2
# stay_38 3
# stay_39 4
# sat
# 40 34
# Ulimate Cost 40 154
# Num_timeslot 10 Optimal_cost 34
# schedule_40 4
# schedule_41 4
# schedule_42 0
# schedule_43 3
# schedule_44 3
# schedule_45 3
# schedule_46 3
# schedule_47 3
# schedule_48 3
# schedule_49 3
# stay_40 5
# stay_41 6
# stay_42 1
# stay_43 1
# stay_44 2
# stay_45 3
# stay_46 4
# stay_47 5
# stay_48 6
# stay_49 7
# sat
# 50 40
# Ulimate Cost 50 194
# Num_timeslot 10 Optimal_cost 40
# schedule_50 3
# schedule_51 3
# schedule_52 3
# schedule_53 3
# schedule_54 3
# schedule_55 3
# schedule_56 3
# schedule_57 3
# schedule_58 3
# schedule_59 3
# stay_50 8
# stay_51 9
# stay_52 10
# stay_53 11
# stay_54 12
# stay_55 13
# stay_56 14
# stay_57 15
# stay_58 16
# stay_59 17
# sat
# 60 36
# Ulimate Cost 60 230
# Num_timeslot 10 Optimal_cost 36
# schedule_60 3
# schedule_61 3
# schedule_62 3
# schedule_63 3
# schedule_64 3
# schedule_65 3
# schedule_66 4
# schedule_67 4
# schedule_68 4
# schedule_69 4
# stay_60 18
# stay_61 19
# stay_62 20
# stay_63 21
# stay_64 22
# stay_65 23
# stay_66 1
# stay_67 2
# stay_68 3
# stay_69 4
# sat
# 70 30
# Ulimate Cost 70 260
# Num_timeslot 10 Optimal_cost 30
# schedule_70 4
# schedule_71 4
# schedule_72 4
# schedule_73 4
# schedule_74 4
# schedule_75 4
# schedule_76 4
# schedule_77 4
# schedule_78 4
# schedule_79 4
# stay_70 5
# stay_71 6
# stay_72 7
# stay_73 8
# stay_74 9
# stay_75 10
# stay_76 11
# stay_77 12
# stay_78 13
# stay_79 14
# sat
# 80 27
# Ulimate Cost 80 287
# Num_timeslot 10 Optimal_cost 27
# schedule_80 4
# schedule_81 0
# schedule_82 4
# schedule_83 4
# schedule_84 4
# schedule_85 4
# schedule_86 4
# schedule_87 4
# schedule_88 4
# schedule_89 4
# stay_80 15
# stay_81 1
# stay_82 1
# stay_83 2
# stay_84 3
# stay_85 4
# stay_86 5
# stay_87 6
# stay_88 7
# stay_89 8
# sat
# 90 27
# Ulimate Cost 90 314
# Num_timeslot 10 Optimal_cost 27
# schedule_90 4
# schedule_91 4
# schedule_92 0
# schedule_93 4
# schedule_94 4
# schedule_95 4
# schedule_96 4
# schedule_97 4
# schedule_98 4
# schedule_99 4
# stay_90 9
# stay_91 10
# stay_92 1
# stay_93 1
# stay_94 2
# stay_95 3
# stay_96 4
# stay_97 5
# stay_98 6
# stay_99 7
# sat
# 100 33
# Ulimate Cost 100 347
# Num_timeslot 10 Optimal_cost 33
# schedule_100 4
# schedule_101 4
# schedule_102 4
# schedule_103 4
# schedule_104 4
# schedule_105 4
# schedule_106 4
# schedule_107 3
# schedule_108 3
# schedule_109 3
# stay_100 8
# stay_101 9
# stay_102 10
# stay_103 11
# stay_104 12
# stay_105 13
# stay_106 14
# stay_107 1
# stay_108 2
# stay_109 3
# sat
# 110 40
# Ulimate Cost 110 387
# Num_timeslot 10 Optimal_cost 40
# schedule_110 3
# schedule_111 3
# schedule_112 3
# schedule_113 3
# schedule_114 3
# schedule_115 3
# schedule_116 3
# schedule_117 3
# schedule_118 3
# schedule_119 3
# stay_110 4
# stay_111 5
# stay_112 6
# stay_113 7
# stay_114 8
# stay_115 9
# stay_116 10
# stay_117 11
# stay_118 12
# stay_119 13
# sat
# 120 32
# Ulimate Cost 120 419
# Num_timeslot 10 Optimal_cost 32
# schedule_120 3
# schedule_121 3
# schedule_122 4
# schedule_123 4
# schedule_124 4
# schedule_125 4
# schedule_126 4
# schedule_127 4
# schedule_128 4
# schedule_129 4
# stay_120 14
# stay_121 15
# stay_122 1
# stay_123 2
# stay_124 3
# stay_125 4
# stay_126 5
# stay_127 6
# stay_128 7
# stay_129 8
# sat
# 130 27
# Ulimate Cost 130 446
# Num_timeslot 10 Optimal_cost 27
# schedule_130 4
# schedule_131 4
# schedule_132 4
# schedule_133 0
# schedule_134 4
# schedule_135 4
# schedule_136 4
# schedule_137 4
# schedule_138 4
# schedule_139 4
# stay_130 9
# stay_131 10
# stay_132 11
# stay_133 1
# stay_134 1
# stay_135 2
# stay_136 3
# stay_137 4
# stay_138 5
# stay_139 6
# sat
# 140 27
# Ulimate Cost 140 473
# Num_timeslot 10 Optimal_cost 27
# schedule_140 4
# schedule_141 4
# schedule_142 4
# schedule_143 4
# schedule_144 0
# schedule_145 4
# schedule_146 4
# schedule_147 4
# schedule_148 4
# schedule_149 4
# stay_140 7
# stay_141 8
# stay_142 9
# stay_143 10
# stay_144 1
# stay_145 1
# stay_146 2
# stay_147 3
# stay_148 4
# stay_149 5
# sat
# 150 27
# Ulimate Cost 150 500
# Num_timeslot 10 Optimal_cost 27
# schedule_150 4
# schedule_151 4
# schedule_152 4
# schedule_153 0
# schedule_154 4
# schedule_155 4
# schedule_156 4
# schedule_157 4
# schedule_158 4
# schedule_159 4
# stay_150 6
# stay_151 7
# stay_152 8
# stay_153 1
# stay_154 1
# stay_155 2
# stay_156 3
# stay_157 4
# stay_158 5
# stay_159 6
# sat
# 160 30
# Ulimate Cost 160 530
# Num_timeslot 10 Optimal_cost 30
# schedule_160 4
# schedule_161 4
# schedule_162 2
# schedule_163 2
# schedule_164 0
# schedule_165 3
# schedule_166 3
# schedule_167 3
# schedule_168 3
# schedule_169 3
# stay_160 7
# stay_161 8
# stay_162 1
# stay_163 2
# stay_164 1
# stay_165 1
# stay_166 2
# stay_167 3
# stay_168 4
# stay_169 5
# sat
# 170 40
# Ulimate Cost 170 570
# Num_timeslot 10 Optimal_cost 40
# schedule_170 3
# schedule_171 3
# schedule_172 3
# schedule_173 3
# schedule_174 3
# schedule_175 3
# schedule_176 3
# schedule_177 3
# schedule_178 3
# schedule_179 3
# stay_170 6
# stay_171 7
# stay_172 8
# stay_173 9
# stay_174 10
# stay_175 11
# stay_176 12
# stay_177 13
# stay_178 14
# stay_179 15
# sat
# 180 21
# Ulimate Cost 180 591
# Num_timeslot 10 Optimal_cost 21
# schedule_180 3
# schedule_181 3
# schedule_182 3
# schedule_183 3
# schedule_184 0
# schedule_185 1
# schedule_186 1
# schedule_187 1
# schedule_188 1
# schedule_189 1
# stay_180 16
# stay_181 17
# stay_182 18
# stay_183 19
# stay_184 1
# stay_185 1
# stay_186 2
# stay_187 3
# stay_188 4
# stay_189 5
# sat
# 190 10
# Ulimate Cost 190 601
# Num_timeslot 10 Optimal_cost 10
# schedule_190 1
# schedule_191 1
# schedule_192 1
# schedule_193 1
# schedule_194 1
# schedule_195 1
# schedule_196 1
# schedule_197 1
# schedule_198 1
# schedule_199 1
# stay_190 6
# stay_191 7
# stay_192 8
# stay_193 9
# stay_194 10
# stay_195 11
# stay_196 12
# stay_197 13
# stay_198 14
# stay_199 15
# sat
# 200 10
# Ulimate Cost 200 611
# Num_timeslot 10 Optimal_cost 10
# schedule_200 1
# schedule_201 1
# schedule_202 1
# schedule_203 1
# schedule_204 1
# schedule_205 1
# schedule_206 1
# schedule_207 1
# schedule_208 1
# schedule_209 1
# stay_200 16
# stay_201 17
# stay_202 18
# stay_203 19
# stay_204 20
# stay_205 21
# stay_206 22
# stay_207 23
# stay_208 24
# stay_209 25
# sat
# 210 10
# Ulimate Cost 210 621
# Num_timeslot 10 Optimal_cost 10
# schedule_210 1
# schedule_211 1
# schedule_212 1
# schedule_213 1
# schedule_214 1
# schedule_215 1
# schedule_216 1
# schedule_217 1
# schedule_218 1
# schedule_219 1
# stay_210 26
# stay_211 27
# stay_212 28
# stay_213 29
# stay_214 30
# stay_215 31
# stay_216 32
# stay_217 33
# stay_218 34
# stay_219 35
# sat
# 220 24
# Ulimate Cost 220 645
# Num_timeslot 10 Optimal_cost 24
# schedule_220 0
# schedule_221 4
# schedule_222 4
# schedule_223 4
# schedule_224 4
# schedule_225 4
# schedule_226 4
# schedule_227 4
# schedule_228 4
# schedule_229 0
# stay_220 1
# stay_221 1
# stay_222 2
# stay_223 3
# stay_224 4
# stay_225 5
# stay_226 6
# stay_227 7
# stay_228 8
# stay_229 1
# sat
# 230 5
# Ulimate Cost 230 650
# Num_timeslot 10 Optimal_cost 5
# schedule_230 0
# schedule_231 0
# schedule_232 0
# schedule_233 0
# schedule_234 0
# schedule_235 1
# schedule_236 1
# schedule_237 1
# schedule_238 1
# schedule_239 1
# stay_230 2
# stay_231 3
# stay_232 4
# stay_233 5
# stay_234 6
# stay_235 1
# stay_236 2
# stay_237 3
# stay_238 4
# stay_239 5
# sat
# 240 10
# Ulimate Cost 240 660
# Num_timeslot 10 Optimal_cost 10
# schedule_240 1
# schedule_241 1
# schedule_242 1
# schedule_243 1
# schedule_244 1
# schedule_245 1
# schedule_246 1
# schedule_247 1
# schedule_248 1
# schedule_249 1
# stay_240 6
# stay_241 7
# stay_242 8
# stay_243 9
# stay_244 10
# stay_245 11
# stay_246 12
# stay_247 13
# stay_248 14
# stay_249 15
# sat
# 250 10
# Ulimate Cost 250 670
# Num_timeslot 10 Optimal_cost 10
# schedule_250 1
# schedule_251 1
# schedule_252 1
# schedule_253 1
# schedule_254 1
# schedule_255 1
# schedule_256 1
# schedule_257 1
# schedule_258 1
# schedule_259 1
# stay_250 16
# stay_251 17
# stay_252 18
# stay_253 19
# stay_254 20
# stay_255 21
# stay_256 22
# stay_257 23
# stay_258 24
# stay_259 25
# sat
# 260 10
# Ulimate Cost 260 680
# Num_timeslot 10 Optimal_cost 10
# schedule_260 1
# schedule_261 1
# schedule_262 1
# schedule_263 1
# schedule_264 1
# schedule_265 1
# schedule_266 1
# schedule_267 1
# schedule_268 1
# schedule_269 1
# stay_260 26
# stay_261 27
# stay_262 28
# stay_263 29
# stay_264 30
# stay_265 31
# stay_266 32
# stay_267 33
# stay_268 34
# stay_269 35
# sat
# 270 10
# Ulimate Cost 270 690
# Num_timeslot 10 Optimal_cost 10
# schedule_270 1
# schedule_271 1
# schedule_272 1
# schedule_273 1
# schedule_274 1
# schedule_275 1
# schedule_276 1
# schedule_277 1
# schedule_278 1
# schedule_279 1
# stay_270 36
# stay_271 37
# stay_272 38
# stay_273 39
# stay_274 40
# stay_275 41
# stay_276 42
# stay_277 43
# stay_278 44
# stay_279 45
# sat
# 280 10
# Ulimate Cost 280 700
# Num_timeslot 10 Optimal_cost 10
# schedule_280 1
# schedule_281 1
# schedule_282 1
# schedule_283 1
# schedule_284 1
# schedule_285 1
# schedule_286 1
# schedule_287 1
# schedule_288 1
# schedule_289 1
# stay_280 46
# stay_281 47
# stay_282 48
# stay_283 49
# stay_284 50
# stay_285 51
# stay_286 52
# stay_287 53
# stay_288 54
# stay_289 55
# sat
# 290 10
# Ulimate Cost 290 710
# Num_timeslot 10 Optimal_cost 10
# schedule_290 1
# schedule_291 1
# schedule_292 1
# schedule_293 1
# schedule_294 1
# schedule_295 1
# schedule_296 1
# schedule_297 1
# schedule_298 1
# schedule_299 1
# stay_290 56
# stay_291 57
# stay_292 58
# stay_293 59
# stay_294 60
# stay_295 61
# stay_296 62
# stay_297 63
# stay_298 64
# stay_299 65
# sat
# 300 10
# Ulimate Cost 300 720
# Num_timeslot 10 Optimal_cost 10
# schedule_300 1
# schedule_301 1
# schedule_302 1
# schedule_303 1
# schedule_304 1
# schedule_305 1
# schedule_306 1
# schedule_307 1
# schedule_308 1
# schedule_309 1
# stay_300 66
# stay_301 67
# stay_302 68
# stay_303 69
# stay_304 70
# stay_305 71
# stay_306 72
# stay_307 73
# stay_308 74
# stay_309 75
# sat
# 310 10
# Ulimate Cost 310 730
# Num_timeslot 10 Optimal_cost 10
# schedule_310 1
# schedule_311 1
# schedule_312 1
# schedule_313 1
# schedule_314 1
# schedule_315 1
# schedule_316 1
# schedule_317 1
# schedule_318 1
# schedule_319 1
# stay_310 76
# stay_311 77
# stay_312 78
# stay_313 79
# stay_314 80
# stay_315 81
# stay_316 82
# stay_317 83
# stay_318 84
# stay_319 85
# sat
# 320 10
# Ulimate Cost 320 740
# Num_timeslot 10 Optimal_cost 10
# schedule_320 1
# schedule_321 1
# schedule_322 1
# schedule_323 1
# schedule_324 1
# schedule_325 1
# schedule_326 1
# schedule_327 1
# schedule_328 1
# schedule_329 1
# stay_320 86
# stay_321 87
# stay_322 88
# stay_323 89
# stay_324 90
# stay_325 91
# stay_326 92
# stay_327 93
# stay_328 94
# stay_329 95
# sat
# 330 10
# Ulimate Cost 330 750
# Num_timeslot 10 Optimal_cost 10
# schedule_330 1
# schedule_331 1
# schedule_332 1
# schedule_333 1
# schedule_334 1
# schedule_335 1
# schedule_336 1
# schedule_337 1
# schedule_338 1
# schedule_339 1
# stay_330 96
# stay_331 97
# stay_332 98
# stay_333 99
# stay_334 100
# stay_335 101
# stay_336 102
# stay_337 103
# stay_338 104
# stay_339 105
# sat
# 340 10
# Ulimate Cost 340 760
# Num_timeslot 10 Optimal_cost 10
# schedule_340 1
# schedule_341 1
# schedule_342 1
# schedule_343 1
# schedule_344 1
# schedule_345 1
# schedule_346 1
# schedule_347 1
# schedule_348 1
# schedule_349 1
# stay_340 106
# stay_341 107
# stay_342 108
# stay_343 109
# stay_344 110
# stay_345 111
# stay_346 112
# stay_347 113
# stay_348 114
# stay_349 115
# sat
# 350 10
# Ulimate Cost 350 770
# Num_timeslot 10 Optimal_cost 10
# schedule_350 1
# schedule_351 1
# schedule_352 1
# schedule_353 1
# schedule_354 1
# schedule_355 1
# schedule_356 1
# schedule_357 1
# schedule_358 1
# schedule_359 1
# stay_350 116
# stay_351 117
# stay_352 118
# stay_353 119
# stay_354 120
# stay_355 121
# stay_356 122
# stay_357 123
# stay_358 124
# stay_359 125
# sat
# 360 10
# Ulimate Cost 360 780
# Num_timeslot 10 Optimal_cost 10
# schedule_360 1
# schedule_361 1
# schedule_362 1
# schedule_363 1
# schedule_364 1
# schedule_365 1
# schedule_366 1
# schedule_367 1
# schedule_368 1
# schedule_369 1
# stay_360 126
# stay_361 127
# stay_362 128
# stay_363 129
# stay_364 130
# stay_365 131
# stay_366 132
# stay_367 133
# stay_368 134
# stay_369 135
# sat
# 370 10
# Ulimate Cost 370 790
# Num_timeslot 10 Optimal_cost 10
# schedule_370 1
# schedule_371 1
# schedule_372 1
# schedule_373 1
# schedule_374 1
# schedule_375 1
# schedule_376 1
# schedule_377 1
# schedule_378 1
# schedule_379 1
# stay_370 136
# stay_371 137
# stay_372 138
# stay_373 139
# stay_374 140
# stay_375 141
# stay_376 142
# stay_377 143
# stay_378 144
# stay_379 145
# sat
# 380 10
# Ulimate Cost 380 800
# Num_timeslot 10 Optimal_cost 10
# schedule_380 1
# schedule_381 1
# schedule_382 1
# schedule_383 1
# schedule_384 1
# schedule_385 1
# schedule_386 1
# schedule_387 1
# schedule_388 1
# schedule_389 1
# stay_380 146
# stay_381 147
# stay_382 148
# stay_383 149
# stay_384 150
# stay_385 151
# stay_386 152
# stay_387 153
# stay_388 154
# stay_389 155
# sat
# 390 10
# Ulimate Cost 390 810
# Num_timeslot 10 Optimal_cost 10
# schedule_390 1
# schedule_391 1
# schedule_392 1
# schedule_393 1
# schedule_394 1
# schedule_395 1
# schedule_396 1
# schedule_397 1
# schedule_398 1
# schedule_399 1
# stay_390 156
# stay_391 157
# stay_392 158
# stay_393 159
# stay_394 160
# stay_395 161
# stay_396 162
# stay_397 163
# stay_398 164
# stay_399 165
# sat
# 400 10
# Ulimate Cost 400 820
# Num_timeslot 10 Optimal_cost 10
# schedule_400 1
# schedule_401 1
# schedule_402 1
# schedule_403 1
# schedule_404 1
# schedule_405 1
# schedule_406 1
# schedule_407 1
# schedule_408 1
# schedule_409 1
# stay_400 166
# stay_401 167
# stay_402 168
# stay_403 169
# stay_404 170
# stay_405 171
# stay_406 172
# stay_407 173
# stay_408 174
# stay_409 175
# sat
# 410 10
# Ulimate Cost 410 830
# Num_timeslot 10 Optimal_cost 10
# schedule_410 1
# schedule_411 1
# schedule_412 1
# schedule_413 1
# schedule_414 1
# schedule_415 1
# schedule_416 1
# schedule_417 1
# schedule_418 1
# schedule_419 1
# stay_410 176
# stay_411 177
# stay_412 178
# stay_413 179
# stay_414 180
# stay_415 181
# stay_416 182
# stay_417 183
# stay_418 184
# stay_419 185
# sat
# 420 10
# Ulimate Cost 420 840
# Num_timeslot 10 Optimal_cost 10
# schedule_420 1
# schedule_421 1
# schedule_422 1
# schedule_423 1
# schedule_424 1
# schedule_425 1
# schedule_426 1
# schedule_427 1
# schedule_428 1
# schedule_429 1
# stay_420 186
# stay_421 187
# stay_422 188
# stay_423 189
# stay_424 190
# stay_425 191
# stay_426 192
# stay_427 193
# stay_428 194
# stay_429 195
# sat
# 430 10
# Ulimate Cost 430 850
# Num_timeslot 10 Optimal_cost 10
# schedule_430 1
# schedule_431 1
# schedule_432 1
# schedule_433 1
# schedule_434 1
# schedule_435 1
# schedule_436 1
# schedule_437 1
# schedule_438 1
# schedule_439 1
# stay_430 196
# stay_431 197
# stay_432 198
# stay_433 199
# stay_434 200
# stay_435 201
# stay_436 202
# stay_437 203
# stay_438 204
# stay_439 205
# sat
# 440 10
# Ulimate Cost 440 860
# Num_timeslot 10 Optimal_cost 10
# schedule_440 1
# schedule_441 1
# schedule_442 1
# schedule_443 1
# schedule_444 1
# schedule_445 1
# schedule_446 1
# schedule_447 1
# schedule_448 1
# schedule_449 1
# stay_440 206
# stay_441 207
# stay_442 208
# stay_443 209
# stay_444 210
# stay_445 211
# stay_446 212
# stay_447 213
# stay_448 214
# stay_449 215
# sat
# 450 10
# Ulimate Cost 450 870
# Num_timeslot 10 Optimal_cost 10
# schedule_450 1
# schedule_451 1
# schedule_452 1
# schedule_453 1
# schedule_454 1
# schedule_455 1
# schedule_456 1
# schedule_457 1
# schedule_458 1
# schedule_459 1
# stay_450 216
# stay_451 217
# stay_452 218
# stay_453 219
# stay_454 220
# stay_455 221
# stay_456 222
# stay_457 223
# stay_458 224
# stay_459 225
# sat
# 460 10
# Ulimate Cost 460 880
# Num_timeslot 10 Optimal_cost 10
# schedule_460 1
# schedule_461 1
# schedule_462 1
# schedule_463 1
# schedule_464 1
# schedule_465 1
# schedule_466 1
# schedule_467 1
# schedule_468 1
# schedule_469 1
# stay_460 226
# stay_461 227
# stay_462 228
# stay_463 229
# stay_464 230
# stay_465 231
# stay_466 232
# stay_467 233
# stay_468 234
# stay_469 235
# sat
# 470 10
# Ulimate Cost 470 890
# Num_timeslot 10 Optimal_cost 10
# schedule_470 1
# schedule_471 1
# schedule_472 1
# schedule_473 1
# schedule_474 1
# schedule_475 1
# schedule_476 1
# schedule_477 1
# schedule_478 1
# schedule_479 1
# stay_470 236
# stay_471 237
# stay_472 238
# stay_473 239
# stay_474 240
# stay_475 241
# stay_476 242
# stay_477 243
# stay_478 244
# stay_479 245
# sat
# 480 10
# Ulimate Cost 480 900
# Num_timeslot 10 Optimal_cost 10
# schedule_480 1
# schedule_481 1
# schedule_482 1
# schedule_483 1
# schedule_484 1
# schedule_485 1
# schedule_486 1
# schedule_487 1
# schedule_488 1
# schedule_489 1
# stay_480 246
# stay_481 247
# stay_482 248
# stay_483 249
# stay_484 250
# stay_485 251
# stay_486 252
# stay_487 253
# stay_488 254
# stay_489 255
# sat
# 490 10
# Ulimate Cost 490 910
# Num_timeslot 10 Optimal_cost 10
# schedule_490 1
# schedule_491 1
# schedule_492 1
# schedule_493 1
# schedule_494 1
# schedule_495 1
# schedule_496 1
# schedule_497 1
# schedule_498 1
# schedule_499 1
# stay_490 256
# stay_491 257
# stay_492 258
# stay_493 259
# stay_494 260
# stay_495 261
# stay_496 262
# stay_497 263
# stay_498 264
# stay_499 265
# sat
# 500 10
# Ulimate Cost 500 920
# Num_timeslot 10 Optimal_cost 10
# schedule_500 1
# schedule_501 1
# schedule_502 1
# schedule_503 1
# schedule_504 1
# schedule_505 1
# schedule_506 1
# schedule_507 1
# schedule_508 1
# schedule_509 1
# stay_500 266
# stay_501 267
# stay_502 268
# stay_503 269
# stay_504 270
# stay_505 271
# stay_506 272
# stay_507 273
# stay_508 274
# stay_509 275
# sat
# 510 10
# Ulimate Cost 510 930
# Num_timeslot 10 Optimal_cost 10
# schedule_510 1
# schedule_511 1
# schedule_512 1
# schedule_513 1
# schedule_514 1
# schedule_515 1
# schedule_516 1
# schedule_517 1
# schedule_518 1
# schedule_519 1
# stay_510 276
# stay_511 277
# stay_512 278
# stay_513 279
# stay_514 280
# stay_515 281
# stay_516 282
# stay_517 283
# stay_518 284
# stay_519 285
# sat
# 520 10
# Ulimate Cost 520 940
# Num_timeslot 10 Optimal_cost 10
# schedule_520 1
# schedule_521 1
# schedule_522 1
# schedule_523 1
# schedule_524 1
# schedule_525 1
# schedule_526 1
# schedule_527 1
# schedule_528 1
# schedule_529 1
# stay_520 286
# stay_521 287
# stay_522 288
# stay_523 289
# stay_524 290
# stay_525 291
# stay_526 292
# stay_527 293
# stay_528 294
# stay_529 295
# sat
# 530 10
# Ulimate Cost 530 950
# Num_timeslot 10 Optimal_cost 10
# schedule_530 1
# schedule_531 1
# schedule_532 1
# schedule_533 1
# schedule_534 1
# schedule_535 1
# schedule_536 1
# schedule_537 1
# schedule_538 1
# schedule_539 1
# stay_530 296
# stay_531 297
# stay_532 298
# stay_533 299
# stay_534 300
# stay_535 301
# stay_536 302
# stay_537 303
# stay_538 304
# stay_539 305
# sat
# 540 10
# Ulimate Cost 540 960
# Num_timeslot 10 Optimal_cost 10
# schedule_540 1
# schedule_541 1
# schedule_542 1
# schedule_543 1
# schedule_544 1
# schedule_545 1
# schedule_546 1
# schedule_547 1
# schedule_548 1
# schedule_549 1
# stay_540 306
# stay_541 307
# stay_542 308
# stay_543 309
# stay_544 310
# stay_545 311
# stay_546 312
# stay_547 313
# stay_548 314
# stay_549 315
# sat
# 550 10
# Ulimate Cost 550 970
# Num_timeslot 10 Optimal_cost 10
# schedule_550 1
# schedule_551 1
# schedule_552 1
# schedule_553 1
# schedule_554 1
# schedule_555 1
# schedule_556 1
# schedule_557 1
# schedule_558 1
# schedule_559 1
# stay_550 316
# stay_551 317
# stay_552 318
# stay_553 319
# stay_554 320
# stay_555 321
# stay_556 322
# stay_557 323
# stay_558 324
# stay_559 325
# sat
# 560 16
# Ulimate Cost 560 986
# Num_timeslot 10 Optimal_cost 16
# schedule_560 1
# schedule_561 1
# schedule_562 1
# schedule_563 1
# schedule_564 0
# schedule_565 4
# schedule_566 4
# schedule_567 4
# schedule_568 4
# schedule_569 0
# stay_560 326
# stay_561 327
# stay_562 328
# stay_563 329
# stay_564 1
# stay_565 1
# stay_566 2
# stay_567 3
# stay_568 4
# stay_569 1
# sat
# 570 32
# Ulimate Cost 570 1018
# Num_timeslot 10 Optimal_cost 32
# schedule_570 0
# schedule_571 0
# schedule_572 3
# schedule_573 3
# schedule_574 3
# schedule_575 3
# schedule_576 3
# schedule_577 3
# schedule_578 3
# schedule_579 3
# stay_570 2
# stay_571 3
# stay_572 1
# stay_573 2
# stay_574 3
# stay_575 4
# stay_576 5
# stay_577 6
# stay_578 7
# stay_579 8
# sat
# 580 31
# Ulimate Cost 580 1049
# Num_timeslot 10 Optimal_cost 31
# schedule_580 3
# schedule_581 4
# schedule_582 4
# schedule_583 4
# schedule_584 4
# schedule_585 4
# schedule_586 4
# schedule_587 4
# schedule_588 4
# schedule_589 4
# stay_580 9
# stay_581 1
# stay_582 2
# stay_583 3
# stay_584 4
# stay_585 5
# stay_586 6
# stay_587 7
# stay_588 8
# stay_589 9
# sat
# 590 40
# Ulimate Cost 590 1089
# Num_timeslot 10 Optimal_cost 40
# schedule_590 3
# schedule_591 3
# schedule_592 3
# schedule_593 3
# schedule_594 3
# schedule_595 3
# schedule_596 3
# schedule_597 3
# schedule_598 3
# schedule_599 3
# stay_590 1
# stay_591 2
# stay_592 3
# stay_593 4
# stay_594 5
# stay_595 6
# stay_596 7
# stay_597 8
# stay_598 9
# stay_599 10
# sat
# 600 40
# Ulimate Cost 600 1129
# Num_timeslot 10 Optimal_cost 40
# schedule_600 3
# schedule_601 3
# schedule_602 3
# schedule_603 3
# schedule_604 3
# schedule_605 3
# schedule_606 3
# schedule_607 3
# schedule_608 3
# schedule_609 3
# stay_600 11
# stay_601 12
# stay_602 13
# stay_603 14
# stay_604 15
# stay_605 16
# stay_606 17
# stay_607 18
# stay_608 19
# stay_609 20
# sat
# 610 40
# Ulimate Cost 610 1169
# Num_timeslot 10 Optimal_cost 40
# schedule_610 3
# schedule_611 3
# schedule_612 3
# schedule_613 3
# schedule_614 3
# schedule_615 3
# schedule_616 3
# schedule_617 3
# schedule_618 3
# schedule_619 3
# stay_610 21
# stay_611 22
# stay_612 23
# stay_613 24
# stay_614 25
# stay_615 26
# stay_616 27
# stay_617 28
# stay_618 29
# stay_619 30
# sat
# 620 38
# Ulimate Cost 620 1207
# Num_timeslot 10 Optimal_cost 38
# schedule_620 3
# schedule_621 3
# schedule_622 3
# schedule_623 3
# schedule_624 3
# schedule_625 3
# schedule_626 4
# schedule_627 4
# schedule_628 3
# schedule_629 3
# stay_620 31
# stay_621 32
# stay_622 33
# stay_623 34
# stay_624 35
# stay_625 36
# stay_626 1
# stay_627 2
# stay_628 1
# stay_629 2
# sat
# 630 38
# Ulimate Cost 630 1245
# Num_timeslot 10 Optimal_cost 38
# schedule_630 3
# schedule_631 3
# schedule_632 3
# schedule_633 3
# schedule_634 3
# schedule_635 4
# schedule_636 4
# schedule_637 3
# schedule_638 3
# schedule_639 3
# stay_630 3
# stay_631 4
# stay_632 5
# stay_633 6
# stay_634 7
# stay_635 1
# stay_636 2
# stay_637 1
# stay_638 2
# stay_639 3
# sat
# 640 40
# Ulimate Cost 640 1285
# Num_timeslot 10 Optimal_cost 40
# schedule_640 3
# schedule_641 3
# schedule_642 3
# schedule_643 3
# schedule_644 3
# schedule_645 3
# schedule_646 3
# schedule_647 3
# schedule_648 3
# schedule_649 3
# stay_640 4
# stay_641 5
# stay_642 6
# stay_643 7
# stay_644 8
# stay_645 9
# stay_646 10
# stay_647 11
# stay_648 12
# stay_649 13
# sat
# 650 38
# Ulimate Cost 650 1323
# Num_timeslot 10 Optimal_cost 38
# schedule_650 4
# schedule_651 4
# schedule_652 3
# schedule_653 3
# schedule_654 3
# schedule_655 3
# schedule_656 3
# schedule_657 3
# schedule_658 3
# schedule_659 3
# stay_650 1
# stay_651 2
# stay_652 1
# stay_653 2
# stay_654 3
# stay_655 4
# stay_656 5
# stay_657 6
# stay_658 7
# stay_659 8
# sat
# 660 40
# Ulimate Cost 660 1363
# Num_timeslot 10 Optimal_cost 40
# schedule_660 3
# schedule_661 3
# schedule_662 3
# schedule_663 3
# schedule_664 3
# schedule_665 3
# schedule_666 3
# schedule_667 3
# schedule_668 3
# schedule_669 3
# stay_660 9
# stay_661 10
# stay_662 11
# stay_663 12
# stay_664 13
# stay_665 14
# stay_666 15
# stay_667 16
# stay_668 17
# stay_669 18
# sat
# 670 40
# Ulimate Cost 670 1403
# Num_timeslot 10 Optimal_cost 40
# schedule_670 3
# schedule_671 3
# schedule_672 3
# schedule_673 3
# schedule_674 3
# schedule_675 3
# schedule_676 3
# schedule_677 3
# schedule_678 3
# schedule_679 3
# stay_670 19
# stay_671 20
# stay_672 21
# stay_673 22
# stay_674 23
# stay_675 24
# stay_676 25
# stay_677 26
# stay_678 27
# stay_679 28
# sat
# 680 40
# Ulimate Cost 680 1443
# Num_timeslot 10 Optimal_cost 40
# schedule_680 3
# schedule_681 3
# schedule_682 3
# schedule_683 3
# schedule_684 3
# schedule_685 3
# schedule_686 3
# schedule_687 3
# schedule_688 3
# schedule_689 3
# stay_680 29
# stay_681 30
# stay_682 31
# stay_683 32
# stay_684 33
# stay_685 34
# stay_686 35
# stay_687 36
# stay_688 37
# stay_689 38
# sat
# 690 40
# Ulimate Cost 690 1483
# Num_timeslot 10 Optimal_cost 40
# schedule_690 3
# schedule_691 3
# schedule_692 3
# schedule_693 3
# schedule_694 3
# schedule_695 3
# schedule_696 3
# schedule_697 3
# schedule_698 3
# schedule_699 3
# stay_690 39
# stay_691 40
# stay_692 41
# stay_693 42
# stay_694 43
# stay_695 44
# stay_696 45
# stay_697 46
# stay_698 47
# stay_699 48
# sat
# 700 38
# Ulimate Cost 700 1521
# Num_timeslot 10 Optimal_cost 38
# schedule_700 4
# schedule_701 4
# schedule_702 3
# schedule_703 3
# schedule_704 3
# schedule_705 3
# schedule_706 3
# schedule_707 3
# schedule_708 3
# schedule_709 3
# stay_700 1
# stay_701 2
# stay_702 1
# stay_703 2
# stay_704 3
# stay_705 4
# stay_706 5
# stay_707 6
# stay_708 7
# stay_709 8
# sat
# 710 38
# Ulimate Cost 710 1559
# Num_timeslot 10 Optimal_cost 38
# schedule_710 4
# schedule_711 4
# schedule_712 3
# schedule_713 3
# schedule_714 3
# schedule_715 3
# schedule_716 3
# schedule_717 3
# schedule_718 3
# schedule_719 3
# stay_710 1
# stay_711 2
# stay_712 1
# stay_713 2
# stay_714 3
# stay_715 4
# stay_716 5
# stay_717 6
# stay_718 7
# stay_719 8
# sat
# 720 32
# Ulimate Cost 720 1591
# Num_timeslot 10 Optimal_cost 32
# schedule_720 3
# schedule_721 3
# schedule_722 4
# schedule_723 4
# schedule_724 4
# schedule_725 4
# schedule_726 4
# schedule_727 4
# schedule_728 4
# schedule_729 4
# stay_720 9
# stay_721 10
# stay_722 1
# stay_723 2
# stay_724 3
# stay_725 4
# stay_726 5
# stay_727 6
# stay_728 7
# stay_729 8
# sat
# 730 36
# Ulimate Cost 730 1627
# Num_timeslot 10 Optimal_cost 36
# schedule_730 4
# schedule_731 4
# schedule_732 4
# schedule_733 4
# schedule_734 3
# schedule_735 3
# schedule_736 3
# schedule_737 3
# schedule_738 3
# schedule_739 3
# stay_730 9
# stay_731 10
# stay_732 11
# stay_733 12
# stay_734 1
# stay_735 2
# stay_736 3
# stay_737 4
# stay_738 5
# stay_739 6
# sat
# 740 37
# Ulimate Cost 740 1664
# Num_timeslot 10 Optimal_cost 37
# schedule_740 3
# schedule_741 3
# schedule_742 3
# schedule_743 4
# schedule_744 4
# schedule_745 4
# schedule_746 3
# schedule_747 3
# schedule_748 3
# schedule_749 3
# stay_740 7
# stay_741 8
# stay_742 9
# stay_743 1
# stay_744 2
# stay_745 3
# stay_746 1
# stay_747 2
# stay_748 3
# stay_749 4
# sat
# 750 31
# Ulimate Cost 750 1695
# Num_timeslot 10 Optimal_cost 31
# schedule_750 3
# schedule_751 4
# schedule_752 4
# schedule_753 4
# schedule_754 4
# schedule_755 4
# schedule_756 4
# schedule_757 4
# schedule_758 4
# schedule_759 4
# stay_750 5
# stay_751 1
# stay_752 2
# stay_753 3
# stay_754 4
# stay_755 5
# stay_756 6
# stay_757 7
# stay_758 8
# stay_759 9
# sat
# 760 31
# Ulimate Cost 760 1726
# Num_timeslot 10 Optimal_cost 31
# schedule_760 4
# schedule_761 0
# schedule_762 4
# schedule_763 4
# schedule_764 4
# schedule_765 4
# schedule_766 3
# schedule_767 3
# schedule_768 3
# schedule_769 3
# stay_760 10
# stay_761 1
# stay_762 1
# stay_763 2
# stay_764 3
# stay_765 4
# stay_766 1
# stay_767 2
# stay_768 3
# stay_769 4
# sat
# 770 40
# Ulimate Cost 770 1766
# Num_timeslot 10 Optimal_cost 40
# schedule_770 3
# schedule_771 3
# schedule_772 3
# schedule_773 3
# schedule_774 3
# schedule_775 3
# schedule_776 3
# schedule_777 3
# schedule_778 3
# schedule_779 3
# stay_770 5
# stay_771 6
# stay_772 7
# stay_773 8
# stay_774 9
# stay_775 10
# stay_776 11
# stay_777 12
# stay_778 13
# stay_779 14
# sat
# 780 40
# Ulimate Cost 780 1806
# Num_timeslot 10 Optimal_cost 40
# schedule_780 3
# schedule_781 3
# schedule_782 3
# schedule_783 3
# schedule_784 3
# schedule_785 3
# schedule_786 3
# schedule_787 3
# schedule_788 3
# schedule_789 3
# stay_780 15
# stay_781 16
# stay_782 17
# stay_783 18
# stay_784 19
# stay_785 20
# stay_786 21
# stay_787 22
# stay_788 23
# stay_789 24
# sat
# 790 40
# Ulimate Cost 790 1846
# Num_timeslot 10 Optimal_cost 40
# schedule_790 3
# schedule_791 3
# schedule_792 3
# schedule_793 3
# schedule_794 3
# schedule_795 3
# schedule_796 3
# schedule_797 3
# schedule_798 3
# schedule_799 3
# stay_790 25
# stay_791 26
# stay_792 27
# stay_793 28
# stay_794 29
# stay_795 30
# stay_796 31
# stay_797 32
# stay_798 33
# stay_799 34
# sat
# 800 33
# Ulimate Cost 800 1879
# Num_timeslot 10 Optimal_cost 33
# schedule_800 3
# schedule_801 3
# schedule_802 3
# schedule_803 4
# schedule_804 4
# schedule_805 4
# schedule_806 4
# schedule_807 4
# schedule_808 4
# schedule_809 4
# stay_800 35
# stay_801 36
# stay_802 37
# stay_803 1
# stay_804 2
# stay_805 3
# stay_806 4
# stay_807 5
# stay_808 6
# stay_809 7
# sat
# 810 35
# Ulimate Cost 810 1914
# Num_timeslot 10 Optimal_cost 35
# schedule_810 4
# schedule_811 4
# schedule_812 4
# schedule_813 4
# schedule_814 4
# schedule_815 3
# schedule_816 3
# schedule_817 3
# schedule_818 3
# schedule_819 3
# stay_810 8
# stay_811 9
# stay_812 10
# stay_813 11
# stay_814 12
# stay_815 1
# stay_816 2
# stay_817 3
# stay_818 4
# stay_819 5
# sat
# 820 20
# Ulimate Cost 820 1934
# Num_timeslot 10 Optimal_cost 20
# schedule_820 2
# schedule_821 2
# schedule_822 2
# schedule_823 2
# schedule_824 2
# schedule_825 2
# schedule_826 2
# schedule_827 2
# schedule_828 2
# schedule_829 2
# stay_820 1
# stay_821 2
# stay_822 3
# stay_823 4
# stay_824 5
# stay_825 6
# stay_826 7
# stay_827 8
# stay_828 9
# stay_829 10
# sat
# 830 20
# Ulimate Cost 830 1954
# Num_timeslot 10 Optimal_cost 20
# schedule_830 2
# schedule_831 2
# schedule_832 2
# schedule_833 2
# schedule_834 2
# schedule_835 2
# schedule_836 2
# schedule_837 2
# schedule_838 2
# schedule_839 2
# stay_830 11
# stay_831 12
# stay_832 13
# stay_833 14
# stay_834 15
# stay_835 16
# stay_836 17
# stay_837 18
# stay_838 19
# stay_839 20
# sat
# 840 20
# Ulimate Cost 840 1974
# Num_timeslot 10 Optimal_cost 20
# schedule_840 2
# schedule_841 2
# schedule_842 2
# schedule_843 2
# schedule_844 2
# schedule_845 2
# schedule_846 2
# schedule_847 2
# schedule_848 2
# schedule_849 2
# stay_840 21
# stay_841 22
# stay_842 23
# stay_843 24
# stay_844 25
# stay_845 26
# stay_846 27
# stay_847 28
# stay_848 29
# stay_849 30
# sat
# 850 22
# Ulimate Cost 850 1996
# Num_timeslot 10 Optimal_cost 22
# schedule_850 2
# schedule_851 2
# schedule_852 2
# schedule_853 2
# schedule_854 2
# schedule_855 2
# schedule_856 2
# schedule_857 2
# schedule_858 4
# schedule_859 4
# stay_850 31
# stay_851 32
# stay_852 33
# stay_853 34
# stay_854 35
# stay_855 36
# stay_856 37
# stay_857 38
# stay_858 1
# stay_859 2
# sat
# 860 31
# Ulimate Cost 860 2027
# Num_timeslot 10 Optimal_cost 31
# schedule_860 4
# schedule_861 4
# schedule_862 3
# schedule_863 4
# schedule_864 4
# schedule_865 4
# schedule_866 4
# schedule_867 4
# schedule_868 4
# schedule_869 4
# stay_860 3
# stay_861 4
# stay_862 1
# stay_863 1
# stay_864 2
# stay_865 3
# stay_866 4
# stay_867 5
# stay_868 6
# stay_869 7
# sat
# 870 38
# Ulimate Cost 870 2065
# Num_timeslot 10 Optimal_cost 38
# schedule_870 4
# schedule_871 4
# schedule_872 3
# schedule_873 3
# schedule_874 3
# schedule_875 3
# schedule_876 3
# schedule_877 3
# schedule_878 3
# schedule_879 3
# stay_870 8
# stay_871 9
# stay_872 1
# stay_873 2
# stay_874 3
# stay_875 4
# stay_876 5
# stay_877 6
# stay_878 7
# stay_879 8
# sat
# 880 40
# Ulimate Cost 880 2105
# Num_timeslot 10 Optimal_cost 40
# schedule_880 3
# schedule_881 3
# schedule_882 3
# schedule_883 3
# schedule_884 3
# schedule_885 3
# schedule_886 3
# schedule_887 3
# schedule_888 3
# schedule_889 3
# stay_880 9
# stay_881 10
# stay_882 11
# stay_883 12
# stay_884 13
# stay_885 14
# stay_886 15
# stay_887 16
# stay_888 17
# stay_889 18
# sat
# 890 40
# Ulimate Cost 890 2145
# Num_timeslot 10 Optimal_cost 40
# schedule_890 3
# schedule_891 3
# schedule_892 3
# schedule_893 3
# schedule_894 3
# schedule_895 3
# schedule_896 3
# schedule_897 3
# schedule_898 3
# schedule_899 3
# stay_890 19
# stay_891 20
# stay_892 21
# stay_893 22
# stay_894 23
# stay_895 24
# stay_896 25
# stay_897 26
# stay_898 27
# stay_899 28
# sat
# 900 40
# Ulimate Cost 900 2185
# Num_timeslot 10 Optimal_cost 40
# schedule_900 3
# schedule_901 3
# schedule_902 3
# schedule_903 3
# schedule_904 3
# schedule_905 3
# schedule_906 3
# schedule_907 3
# schedule_908 3
# schedule_909 3
# stay_900 29
# stay_901 30
# stay_902 31
# stay_903 32
# stay_904 33
# stay_905 34
# stay_906 35
# stay_907 36
# stay_908 37
# stay_909 38
# sat
# 910 40
# Ulimate Cost 910 2225
# Num_timeslot 10 Optimal_cost 40
# schedule_910 3
# schedule_911 3
# schedule_912 3
# schedule_913 3
# schedule_914 3
# schedule_915 3
# schedule_916 3
# schedule_917 3
# schedule_918 3
# schedule_919 3
# stay_910 39
# stay_911 40
# stay_912 41
# stay_913 42
# stay_914 43
# stay_915 44
# stay_916 45
# stay_917 46
# stay_918 47
# stay_919 48
# sat
# 920 36
# Ulimate Cost 920 2261
# Num_timeslot 10 Optimal_cost 36
# schedule_920 3
# schedule_921 3
# schedule_922 3
# schedule_923 3
# schedule_924 3
# schedule_925 0
# schedule_926 3
# schedule_927 3
# schedule_928 3
# schedule_929 3
# stay_920 49
# stay_921 50
# stay_922 51
# stay_923 52
# stay_924 53
# stay_925 1
# stay_926 1
# stay_927 2
# stay_928 3
# stay_929 4
# sat
# 930 40
# Ulimate Cost 930 2301
# Num_timeslot 10 Optimal_cost 40
# schedule_930 3
# schedule_931 3
# schedule_932 3
# schedule_933 3
# schedule_934 3
# schedule_935 3
# schedule_936 3
# schedule_937 3
# schedule_938 3
# schedule_939 3
# stay_930 5
# stay_931 6
# stay_932 7
# stay_933 8
# stay_934 9
# stay_935 10
# stay_936 11
# stay_937 12
# stay_938 13
# stay_939 14
# sat
# 940 40
# Ulimate Cost 940 2341
# Num_timeslot 10 Optimal_cost 40
# schedule_940 3
# schedule_941 3
# schedule_942 3
# schedule_943 3
# schedule_944 3
# schedule_945 3
# schedule_946 3
# schedule_947 3
# schedule_948 3
# schedule_949 3
# stay_940 15
# stay_941 16
# stay_942 17
# stay_943 18
# stay_944 19
# stay_945 20
# stay_946 21
# stay_947 22
# stay_948 23
# stay_949 24
# sat
# 950 40
# Ulimate Cost 950 2381
# Num_timeslot 10 Optimal_cost 40
# schedule_950 3
# schedule_951 3
# schedule_952 3
# schedule_953 3
# schedule_954 3
# schedule_955 3
# schedule_956 3
# schedule_957 3
# schedule_958 3
# schedule_959 3
# stay_950 25
# stay_951 26
# stay_952 27
# stay_953 28
# stay_954 29
# stay_955 30
# stay_956 31
# stay_957 32
# stay_958 33
# stay_959 34
# sat
# 960 36
# Ulimate Cost 960 2417
# Num_timeslot 10 Optimal_cost 36
# schedule_960 3
# schedule_961 3
# schedule_962 3
# schedule_963 3
# schedule_964 3
# schedule_965 3
# schedule_966 3
# schedule_967 3
# schedule_968 3
# schedule_969 0
# stay_960 35
# stay_961 36
# stay_962 37
# stay_963 38
# stay_964 39
# stay_965 40
# stay_966 41
# stay_967 42
# stay_968 43
# stay_969 1
# sat
# 970 36
# Ulimate Cost 970 2453
# Num_timeslot 10 Optimal_cost 36
# schedule_970 0
# schedule_971 3
# schedule_972 3
# schedule_973 3
# schedule_974 3
# schedule_975 3
# schedule_976 3
# schedule_977 3
# schedule_978 3
# schedule_979 3
# stay_970 2
# stay_971 1
# stay_972 2
# stay_973 3
# stay_974 4
# stay_975 5
# stay_976 6
# stay_977 7
# stay_978 8
# stay_979 9
# sat
# 980 25
# Ulimate Cost 980 2478
# Num_timeslot 10 Optimal_cost 25
# schedule_980 3
# schedule_981 4
# schedule_982 4
# schedule_983 0
# schedule_984 4
# schedule_985 4
# schedule_986 0
# schedule_987 4
# schedule_988 4
# schedule_989 4
# stay_980 10
# stay_981 1
# stay_982 2
# stay_983 1
# stay_984 1
# stay_985 2
# stay_986 1
# stay_987 1
# stay_988 2
# stay_989 3
# sat
# 990 23
# Ulimate Cost 990 2501
# Num_timeslot 10 Optimal_cost 23
# schedule_990 0
# schedule_991 4
# schedule_992 4
# schedule_993 4
# schedule_994 0
# schedule_995 4
# schedule_996 4
# schedule_997 4
# schedule_998 4
# schedule_999 2
# stay_990 1
# stay_991 1
# stay_992 2
# stay_993 3
# stay_994 1
# stay_995 1
# stay_996 2
# stay_997 3
# stay_998 4
# stay_999 1
# sat
# 1000 24
# Ulimate Cost 1000 2525
# Num_timeslot 10 Optimal_cost 24
# schedule_1000 2
# schedule_1001 2
# schedule_1002 2
# schedule_1003 2
# schedule_1004 2
# schedule_1005 2
# schedule_1006 2
# schedule_1007 2
# schedule_1008 3
# schedule_1009 3
# stay_1000 2
# stay_1001 3
# stay_1002 4
# stay_1003 5
# stay_1004 6
# stay_1005 7
# stay_1006 8
# stay_1007 9
# stay_1008 1
# stay_1009 2
# sat
# 1010 40
# Ulimate Cost 1010 2565
# Num_timeslot 10 Optimal_cost 40
# schedule_1010 3
# schedule_1011 3
# schedule_1012 3
# schedule_1013 3
# schedule_1014 3
# schedule_1015 3
# schedule_1016 3
# schedule_1017 3
# schedule_1018 3
# schedule_1019 3
# stay_1010 3
# stay_1011 4
# stay_1012 5
# stay_1013 6
# stay_1014 7
# stay_1015 8
# stay_1016 9
# stay_1017 10
# stay_1018 11
# stay_1019 12
# sat
# 1020 40
# Ulimate Cost 1020 2605
# Num_timeslot 10 Optimal_cost 40
# schedule_1020 3
# schedule_1021 3
# schedule_1022 3
# schedule_1023 3
# schedule_1024 3
# schedule_1025 3
# schedule_1026 3
# schedule_1027 3
# schedule_1028 3
# schedule_1029 3
# stay_1020 13
# stay_1021 14
# stay_1022 15
# stay_1023 16
# stay_1024 17
# stay_1025 18
# stay_1026 19
# stay_1027 20
# stay_1028 21
# stay_1029 22
# sat
# 1030 40
# Ulimate Cost 1030 2645
# Num_timeslot 10 Optimal_cost 40
# schedule_1030 3
# schedule_1031 3
# schedule_1032 3
# schedule_1033 3
# schedule_1034 3
# schedule_1035 3
# schedule_1036 3
# schedule_1037 3
# schedule_1038 3
# schedule_1039 3
# stay_1030 23
# stay_1031 24
# stay_1032 25
# stay_1033 26
# stay_1034 27
# stay_1035 28
# stay_1036 29
# stay_1037 30
# stay_1038 31
# stay_1039 32
# sat
# 1040 38
# Ulimate Cost 1040 2683
# Num_timeslot 10 Optimal_cost 38
# schedule_1040 3
# schedule_1041 3
# schedule_1042 3
# schedule_1043 3
# schedule_1044 3
# schedule_1045 3
# schedule_1046 3
# schedule_1047 3
# schedule_1048 3
# schedule_1049 2
# stay_1040 33
# stay_1041 34
# stay_1042 35
# stay_1043 36
# stay_1044 37
# stay_1045 38
# stay_1046 39
# stay_1047 40
# stay_1048 41
# stay_1049 1
# sat
# 1050 32
# Ulimate Cost 1050 2715
# Num_timeslot 10 Optimal_cost 32
# schedule_1050 2
# schedule_1051 2
# schedule_1052 2
# schedule_1053 2
# schedule_1054 3
# schedule_1055 3
# schedule_1056 3
# schedule_1057 3
# schedule_1058 3
# schedule_1059 3
# stay_1050 2
# stay_1051 3
# stay_1052 4
# stay_1053 5
# stay_1054 1
# stay_1055 2
# stay_1056 3
# stay_1057 4
# stay_1058 5
# stay_1059 6
# sat
# 1060 40
# Ulimate Cost 1060 2755
# Num_timeslot 10 Optimal_cost 40
# schedule_1060 3
# schedule_1061 3
# schedule_1062 3
# schedule_1063 3
# schedule_1064 3
# schedule_1065 3
# schedule_1066 3
# schedule_1067 3
# schedule_1068 3
# schedule_1069 3
# stay_1060 7
# stay_1061 8
# stay_1062 9
# stay_1063 10
# stay_1064 11
# stay_1065 12
# stay_1066 13
# stay_1067 14
# stay_1068 15
# stay_1069 16
# sat
# 1070 40
# Ulimate Cost 1070 2795
# Num_timeslot 10 Optimal_cost 40
# schedule_1070 3
# schedule_1071 3
# schedule_1072 3
# schedule_1073 3
# schedule_1074 3
# schedule_1075 3
# schedule_1076 3
# schedule_1077 3
# schedule_1078 3
# schedule_1079 3
# stay_1070 17
# stay_1071 18
# stay_1072 19
# stay_1073 20
# stay_1074 21
# stay_1075 22
# stay_1076 23
# stay_1077 24
# stay_1078 25
# stay_1079 26
# sat
# 1080 34
# Ulimate Cost 1080 2829
# Num_timeslot 10 Optimal_cost 34
# schedule_1080 3
# schedule_1081 3
# schedule_1082 3
# schedule_1083 3
# schedule_1084 3
# schedule_1085 3
# schedule_1086 3
# schedule_1087 0
# schedule_1088 4
# schedule_1089 4
# stay_1080 27
# stay_1081 28
# stay_1082 29
# stay_1083 30
# stay_1084 31
# stay_1085 32
# stay_1086 33
# stay_1087 1
# stay_1088 1
# stay_1089 2
# sat
# 1090 38
# Ulimate Cost 1090 2867
# Num_timeslot 10 Optimal_cost 38
# schedule_1090 4
# schedule_1091 4
# schedule_1092 3
# schedule_1093 3
# schedule_1094 3
# schedule_1095 3
# schedule_1096 3
# schedule_1097 3
# schedule_1098 3
# schedule_1099 3
# stay_1090 3
# stay_1091 4
# stay_1092 1
# stay_1093 2
# stay_1094 3
# stay_1095 4
# stay_1096 5
# stay_1097 6
# stay_1098 7
# stay_1099 8
# sat
# 1100 40
# Ulimate Cost 1100 2907
# Num_timeslot 10 Optimal_cost 40
# schedule_1100 3
# schedule_1101 3
# schedule_1102 3
# schedule_1103 3
# schedule_1104 3
# schedule_1105 3
# schedule_1106 3
# schedule_1107 3
# schedule_1108 3
# schedule_1109 3
# stay_1100 9
# stay_1101 10
# stay_1102 11
# stay_1103 12
# stay_1104 13
# stay_1105 14
# stay_1106 15
# stay_1107 16
# stay_1108 17
# stay_1109 18
# sat
# 1110 40
# Ulimate Cost 1110 2947
# Num_timeslot 10 Optimal_cost 40
# schedule_1110 3
# schedule_1111 3
# schedule_1112 3
# schedule_1113 3
# schedule_1114 3
# schedule_1115 3
# schedule_1116 3
# schedule_1117 3
# schedule_1118 3
# schedule_1119 3
# stay_1110 19
# stay_1111 20
# stay_1112 21
# stay_1113 22
# stay_1114 23
# stay_1115 24
# stay_1116 25
# stay_1117 26
# stay_1118 27
# stay_1119 28
# sat
# 1120 33
# Ulimate Cost 1120 2980
# Num_timeslot 10 Optimal_cost 33
# schedule_1120 3
# schedule_1121 3
# schedule_1122 3
# schedule_1123 0
# schedule_1124 3
# schedule_1125 3
# schedule_1126 3
# schedule_1127 4
# schedule_1128 4
# schedule_1129 4
# stay_1120 29
# stay_1121 30
# stay_1122 31
# stay_1123 1
# stay_1124 1
# stay_1125 2
# stay_1126 3
# stay_1127 1
# stay_1128 2
# stay_1129 3
# sat
# 1130 36
# Ulimate Cost 1130 3016
# Num_timeslot 10 Optimal_cost 36
# schedule_1130 4
# schedule_1131 4
# schedule_1132 4
# schedule_1133 4
# schedule_1134 3
# schedule_1135 3
# schedule_1136 3
# schedule_1137 3
# schedule_1138 3
# schedule_1139 3
# stay_1130 4
# stay_1131 5
# stay_1132 6
# stay_1133 7
# stay_1134 1
# stay_1135 2
# stay_1136 3
# stay_1137 4
# stay_1138 5
# stay_1139 6
# sat
# 1140 38
# Ulimate Cost 1140 3054
# Num_timeslot 10 Optimal_cost 38
# schedule_1140 3
# schedule_1141 3
# schedule_1142 3
# schedule_1143 3
# schedule_1144 3
# schedule_1145 3
# schedule_1146 3
# schedule_1147 3
# schedule_1148 4
# schedule_1149 4
# stay_1140 7
# stay_1141 8
# stay_1142 9
# stay_1143 10
# stay_1144 11
# stay_1145 12
# stay_1146 13
# stay_1147 14
# stay_1148 1
# stay_1149 2
# sat
# 1150 31
# Ulimate Cost 1150 3085
# Num_timeslot 10 Optimal_cost 31
# schedule_1150 4
# schedule_1151 3
# schedule_1152 4
# schedule_1153 4
# schedule_1154 4
# schedule_1155 4
# schedule_1156 4
# schedule_1157 4
# schedule_1158 4
# schedule_1159 4
# stay_1150 3
# stay_1151 1
# stay_1152 1
# stay_1153 2
# stay_1154 3
# stay_1155 4
# stay_1156 5
# stay_1157 6
# stay_1158 7
# stay_1159 8
# sat
# 1160 36
# Ulimate Cost 1160 3121
# Num_timeslot 10 Optimal_cost 36
# schedule_1160 4
# schedule_1161 4
# schedule_1162 4
# schedule_1163 4
# schedule_1164 3
# schedule_1165 3
# schedule_1166 3
# schedule_1167 3
# schedule_1168 3
# schedule_1169 3
# stay_1160 9
# stay_1161 10
# stay_1162 11
# stay_1163 12
# stay_1164 1
# stay_1165 2
# stay_1166 3
# stay_1167 4
# stay_1168 5
# stay_1169 6
# sat
# 1170 32
# Ulimate Cost 1170 3153
# Num_timeslot 10 Optimal_cost 32
# schedule_1170 3
# schedule_1171 3
# schedule_1172 3
# schedule_1173 0
# schedule_1174 0
# schedule_1175 3
# schedule_1176 3
# schedule_1177 3
# schedule_1178 3
# schedule_1179 3
# stay_1170 7
# stay_1171 8
# stay_1172 9
# stay_1173 1
# stay_1174 2
# stay_1175 1
# stay_1176 2
# stay_1177 3
# stay_1178 4
# stay_1179 5
# sat
# 1180 40
# Ulimate Cost 1180 3193
# Num_timeslot 10 Optimal_cost 40
# schedule_1180 3
# schedule_1181 3
# schedule_1182 3
# schedule_1183 3
# schedule_1184 3
# schedule_1185 3
# schedule_1186 3
# schedule_1187 3
# schedule_1188 3
# schedule_1189 3
# stay_1180 6
# stay_1181 7
# stay_1182 8
# stay_1183 9
# stay_1184 10
# stay_1185 11
# stay_1186 12
# stay_1187 13
# stay_1188 14
# stay_1189 15
# sat
# 1190 25
# Ulimate Cost 1190 3218
# Num_timeslot 10 Optimal_cost 25
# schedule_1190 3
# schedule_1191 0
# schedule_1192 0
# schedule_1193 4
# schedule_1194 4
# schedule_1195 4
# schedule_1196 4
# schedule_1197 4
# schedule_1198 4
# schedule_1199 4
# stay_1190 16
# stay_1191 1
# stay_1192 2
# stay_1193 1
# stay_1194 2
# stay_1195 3
# stay_1196 4
# stay_1197 5
# stay_1198 6
# stay_1199 7
# sat
# 1200 30
# Ulimate Cost 1200 3248
# Num_timeslot 10 Optimal_cost 30
# schedule_1200 4
# schedule_1201 4
# schedule_1202 4
# schedule_1203 4
# schedule_1204 4
# schedule_1205 4
# schedule_1206 4
# schedule_1207 4
# schedule_1208 4
# schedule_1209 4
# stay_1200 8
# stay_1201 9
# stay_1202 10
# stay_1203 11
# stay_1204 12
# stay_1205 13
# stay_1206 14
# stay_1207 15
# stay_1208 16
# stay_1209 17
# sat
# 1210 30
# Ulimate Cost 1210 3278
# Num_timeslot 10 Optimal_cost 30
# schedule_1210 4
# schedule_1211 4
# schedule_1212 4
# schedule_1213 4
# schedule_1214 4
# schedule_1215 4
# schedule_1216 4
# schedule_1217 4
# schedule_1218 4
# schedule_1219 4
# stay_1210 18
# stay_1211 19
# stay_1212 20
# stay_1213 21
# stay_1214 22
# stay_1215 23
# stay_1216 24
# stay_1217 25
# stay_1218 26
# stay_1219 27
# sat
# 1220 30
# Ulimate Cost 1220 3308
# Num_timeslot 10 Optimal_cost 30
# schedule_1220 4
# schedule_1221 4
# schedule_1222 4
# schedule_1223 4
# schedule_1224 4
# schedule_1225 4
# schedule_1226 4
# schedule_1227 4
# schedule_1228 4
# schedule_1229 4
# stay_1220 28
# stay_1221 29
# stay_1222 30
# stay_1223 31
# stay_1224 32
# stay_1225 33
# stay_1226 34
# stay_1227 35
# stay_1228 36
# stay_1229 37
# sat
# 1230 30
# Ulimate Cost 1230 3338
# Num_timeslot 10 Optimal_cost 30
# schedule_1230 4
# schedule_1231 4
# schedule_1232 4
# schedule_1233 4
# schedule_1234 4
# schedule_1235 4
# schedule_1236 4
# schedule_1237 4
# schedule_1238 4
# schedule_1239 4
# stay_1230 38
# stay_1231 39
# stay_1232 40
# stay_1233 41
# stay_1234 42
# stay_1235 43
# stay_1236 44
# stay_1237 45
# stay_1238 46
# stay_1239 47
# sat
# 1240 30
# Ulimate Cost 1240 3368
# Num_timeslot 10 Optimal_cost 30
# schedule_1240 4
# schedule_1241 4
# schedule_1242 4
# schedule_1243 4
# schedule_1244 4
# schedule_1245 4
# schedule_1246 4
# schedule_1247 4
# schedule_1248 4
# schedule_1249 4
# stay_1240 48
# stay_1241 49
# stay_1242 50
# stay_1243 51
# stay_1244 52
# stay_1245 53
# stay_1246 54
# stay_1247 55
# stay_1248 56
# stay_1249 57
# sat
# 1250 30
# Ulimate Cost 1250 3398
# Num_timeslot 10 Optimal_cost 30
# schedule_1250 4
# schedule_1251 4
# schedule_1252 4
# schedule_1253 4
# schedule_1254 4
# schedule_1255 4
# schedule_1256 0
# schedule_1257 3
# schedule_1258 3
# schedule_1259 3
# stay_1250 58
# stay_1251 59
# stay_1252 60
# stay_1253 61
# stay_1254 62
# stay_1255 63
# stay_1256 1
# stay_1257 1
# stay_1258 2
# stay_1259 3
# sat
# 1260 40
# Ulimate Cost 1260 3438
# Num_timeslot 10 Optimal_cost 40
# schedule_1260 3
# schedule_1261 3
# schedule_1262 3
# schedule_1263 3
# schedule_1264 3
# schedule_1265 3
# schedule_1266 3
# schedule_1267 3
# schedule_1268 3
# schedule_1269 3
# stay_1260 4
# stay_1261 5
# stay_1262 6
# stay_1263 7
# stay_1264 8
# stay_1265 9
# stay_1266 10
# stay_1267 11
# stay_1268 12
# stay_1269 13
# sat
# 1270 26
# Ulimate Cost 1270 3464
# Num_timeslot 10 Optimal_cost 26
# schedule_1270 0
# schedule_1271 3
# schedule_1272 3
# schedule_1273 3
# schedule_1274 3
# schedule_1275 2
# schedule_1276 2
# schedule_1277 2
# schedule_1278 2
# schedule_1279 2
# stay_1270 1
# stay_1271 1
# stay_1272 2
# stay_1273 3
# stay_1274 4
# stay_1275 1
# stay_1276 2
# stay_1277 3
# stay_1278 4
# stay_1279 5
# sat
# 1280 22
# Ulimate Cost 1280 3486
# Num_timeslot 10 Optimal_cost 22
# schedule_1280 4
# schedule_1281 4
# schedule_1282 2
# schedule_1283 2
# schedule_1284 2
# schedule_1285 2
# schedule_1286 2
# schedule_1287 2
# schedule_1288 2
# schedule_1289 2
# stay_1280 1
# stay_1281 2
# stay_1282 1
# stay_1283 2
# stay_1284 3
# stay_1285 4
# stay_1286 5
# stay_1287 6
# stay_1288 7
# stay_1289 8
# sat
# 1290 28
# Ulimate Cost 1290 3514
# Num_timeslot 10 Optimal_cost 28
# schedule_1290 2
# schedule_1291 2
# schedule_1292 2
# schedule_1293 2
# schedule_1294 2
# schedule_1295 2
# schedule_1296 3
# schedule_1297 3
# schedule_1298 3
# schedule_1299 3
# stay_1290 9
# stay_1291 10
# stay_1292 11
# stay_1293 12
# stay_1294 13
# stay_1295 14
# stay_1296 1
# stay_1297 2
# stay_1298 3
# stay_1299 4
# sat
# 1300 30
# Ulimate Cost 1300 3544
# Num_timeslot 10 Optimal_cost 30
# schedule_1300 3
# schedule_1301 3
# schedule_1302 3
# schedule_1303 3
# schedule_1304 3
# schedule_1305 3
# schedule_1306 0
# schedule_1307 2
# schedule_1308 2
# schedule_1309 2
# stay_1300 5
# stay_1301 6
# stay_1302 7
# stay_1303 8
# stay_1304 9
# stay_1305 10
# stay_1306 1
# stay_1307 1
# stay_1308 2
# stay_1309 3
# sat
# 1310 20
# Ulimate Cost 1310 3564
# Num_timeslot 10 Optimal_cost 20
# schedule_1310 2
# schedule_1311 2
# schedule_1312 2
# schedule_1313 2
# schedule_1314 2
# schedule_1315 2
# schedule_1316 2
# schedule_1317 2
# schedule_1318 2
# schedule_1319 2
# stay_1310 4
# stay_1311 5
# stay_1312 6
# stay_1313 7
# stay_1314 8
# stay_1315 9
# stay_1316 10
# stay_1317 11
# stay_1318 12
# stay_1319 13
# sat
# 1320 38
# Ulimate Cost 1320 3602
# Num_timeslot 10 Optimal_cost 38
# schedule_1320 2
# schedule_1321 3
# schedule_1322 3
# schedule_1323 3
# schedule_1324 3
# schedule_1325 3
# schedule_1326 3
# schedule_1327 3
# schedule_1328 3
# schedule_1329 3
# stay_1320 14
# stay_1321 1
# stay_1322 2
# stay_1323 3
# stay_1324 4
# stay_1325 5
# stay_1326 6
# stay_1327 7
# stay_1328 8
# stay_1329 9
# sat
# 1330 40
# Ulimate Cost 1330 3642
# Num_timeslot 10 Optimal_cost 40
# schedule_1330 3
# schedule_1331 3
# schedule_1332 3
# schedule_1333 3
# schedule_1334 3
# schedule_1335 3
# schedule_1336 3
# schedule_1337 3
# schedule_1338 3
# schedule_1339 3
# stay_1330 10
# stay_1331 11
# stay_1332 12
# stay_1333 13
# stay_1334 14
# stay_1335 15
# stay_1336 16
# stay_1337 17
# stay_1338 18
# stay_1339 19
# sat
# 1340 40
# Ulimate Cost 1340 3682
# Num_timeslot 10 Optimal_cost 40
# schedule_1340 3
# schedule_1341 3
# schedule_1342 3
# schedule_1343 3
# schedule_1344 3
# schedule_1345 3
# schedule_1346 3
# schedule_1347 3
# schedule_1348 3
# schedule_1349 3
# stay_1340 20
# stay_1341 21
# stay_1342 22
# stay_1343 23
# stay_1344 24
# stay_1345 25
# stay_1346 26
# stay_1347 27
# stay_1348 28
# stay_1349 29
# sat
# 1350 28
# Ulimate Cost 1350 3710
# Num_timeslot 10 Optimal_cost 28
# schedule_1350 3
# schedule_1351 3
# schedule_1352 3
# schedule_1353 3
# schedule_1354 2
# schedule_1355 2
# schedule_1356 2
# schedule_1357 2
# schedule_1358 2
# schedule_1359 2
# stay_1350 30
# stay_1351 31
# stay_1352 32
# stay_1353 33
# stay_1354 1
# stay_1355 2
# stay_1356 3
# stay_1357 4
# stay_1358 5
# stay_1359 6
# sat
# 1360 22
# Ulimate Cost 1360 3732
# Num_timeslot 10 Optimal_cost 22
# schedule_1360 2
# schedule_1361 2
# schedule_1362 2
# schedule_1363 2
# schedule_1364 2
# schedule_1365 2
# schedule_1366 2
# schedule_1367 2
# schedule_1368 4
# schedule_1369 4
# stay_1360 7
# stay_1361 8
# stay_1362 9
# stay_1363 10
# stay_1364 11
# stay_1365 12
# stay_1366 13
# stay_1367 14
# stay_1368 1
# stay_1369 2
# sat
# 1370 30
# Ulimate Cost 1370 3762
# Num_timeslot 10 Optimal_cost 30
# schedule_1370 4
# schedule_1371 4
# schedule_1372 0
# schedule_1373 0
# schedule_1374 3
# schedule_1375 3
# schedule_1376 3
# schedule_1377 3
# schedule_1378 3
# schedule_1379 3
# stay_1370 3
# stay_1371 4
# stay_1372 1
# stay_1373 2
# stay_1374 1
# stay_1375 2
# stay_1376 3
# stay_1377 4
# stay_1378 5
# stay_1379 6
# sat
# 1380 27
# Ulimate Cost 1380 3789
# Num_timeslot 10 Optimal_cost 27
# schedule_1380 3
# schedule_1381 4
# schedule_1382 4
# schedule_1383 4
# schedule_1384 4
# schedule_1385 0
# schedule_1386 4
# schedule_1387 4
# schedule_1388 4
# schedule_1389 2
# stay_1380 7
# stay_1381 1
# stay_1382 2
# stay_1383 3
# stay_1384 4
# stay_1385 1
# stay_1386 1
# stay_1387 2
# stay_1388 3
# stay_1389 1
# sat
# 1390 20
# Ulimate Cost 1390 3809
# Num_timeslot 10 Optimal_cost 20
# schedule_1390 2
# schedule_1391 2
# schedule_1392 2
# schedule_1393 2
# schedule_1394 2
# schedule_1395 2
# schedule_1396 2
# schedule_1397 2
# schedule_1398 2
# schedule_1399 2
# stay_1390 2
# stay_1391 3
# stay_1392 4
# stay_1393 5
# stay_1394 6
# stay_1395 7
# stay_1396 8
# stay_1397 9
# stay_1398 10
# stay_1399 11
# sat
# 1400 20
# Ulimate Cost 1400 3829
# Num_timeslot 10 Optimal_cost 20
# schedule_1400 2
# schedule_1401 2
# schedule_1402 2
# schedule_1403 2
# schedule_1404 2
# schedule_1405 2
# schedule_1406 2
# schedule_1407 2
# schedule_1408 2
# schedule_1409 2
# stay_1400 12
# stay_1401 13
# stay_1402 14
# stay_1403 15
# stay_1404 16
# stay_1405 17
# stay_1406 18
# stay_1407 19
# stay_1408 20
# stay_1409 21
# sat
# 1410 20
# Ulimate Cost 1410 3849
# Num_timeslot 10 Optimal_cost 20
# schedule_1410 2
# schedule_1411 2
# schedule_1412 2
# schedule_1413 2
# schedule_1414 2
# schedule_1415 2
# schedule_1416 2
# schedule_1417 2
# schedule_1418 2
# schedule_1419 2
# stay_1410 22
# stay_1411 23
# stay_1412 24
# stay_1413 25
# stay_1414 26
# stay_1415 27
# stay_1416 28
# stay_1417 29
# stay_1418 30
# stay_1419 31
# sat
# 1420 22
# Ulimate Cost 1420 3871
# Num_timeslot 10 Optimal_cost 22
# schedule_1420 2
# schedule_1421 2
# schedule_1422 2
# schedule_1423 2
# schedule_1424 2
# ...
# stay_501 16
# stay_502 17
# stay_503 18
# stay_504 19
# stay_505 20
# stay_506 21
# stay_507 22
# stay_508 23
# stay_509 24
# sat
# 510 39
# Ulimate Cost 510 1976
# Num_timeslot 10 Optimal_cost 39
# schedule_510 4
# schedule_511 3
# schedule_512 3
# schedule_513 3
# schedule_514 3
# schedule_515 3
# schedule_516 3
# schedule_517 3
# schedule_518 3
# schedule_519 3
# stay_510 1
# stay_511 1
# stay_512 2
# stay_513 3
# stay_514 4
# stay_515 5
# stay_516 6
# stay_517 7
# stay_518 8
# stay_519 9
# sat
# 520 40
# Ulimate Cost 520 2016
# Num_timeslot 10 Optimal_cost 40
# schedule_520 3
# schedule_521 3
# schedule_522 3
# schedule_523 3
# schedule_524 3
# schedule_525 3
# schedule_526 3
# schedule_527 3
# schedule_528 3
# schedule_529 3
# stay_520 10
# stay_521 11
# stay_522 12
# stay_523 13
# stay_524 14
# stay_525 15
# stay_526 16
# stay_527 17
# stay_528 18
# stay_529 19
# sat
# 530 39
# Ulimate Cost 530 2055
# Num_timeslot 10 Optimal_cost 39
# schedule_530 4
# schedule_531 3
# schedule_532 3
# schedule_533 3
# schedule_534 3
# schedule_535 3
# schedule_536 3
# schedule_537 3
# schedule_538 3
# schedule_539 3
# stay_530 1
# stay_531 1
# stay_532 2
# stay_533 3
# stay_534 4
# stay_535 5
# stay_536 6
# stay_537 7
# stay_538 8
# stay_539 9
# sat
# 540 40
# Ulimate Cost 540 2095
# Num_timeslot 10 Optimal_cost 40
# schedule_540 3
# schedule_541 3
# schedule_542 3
# schedule_543 3
# schedule_544 3
# schedule_545 3
# schedule_546 3
# schedule_547 3
# schedule_548 3
# schedule_549 3
# stay_540 10
# stay_541 11
# stay_542 12
# stay_543 13
# stay_544 14
# stay_545 15
# stay_546 16
# stay_547 17
# stay_548 18
# stay_549 19
# sat
# 550 39
# Ulimate Cost 550 2134
# Num_timeslot 10 Optimal_cost 39
# schedule_550 3
# schedule_551 3
# schedule_552 3
# schedule_553 3
# schedule_554 3
# schedule_555 4
# schedule_556 3
# schedule_557 3
# schedule_558 3
# schedule_559 3
# stay_550 20
# stay_551 21
# stay_552 22
# stay_553 23
# stay_554 24
# stay_555 1
# stay_556 1
# stay_557 2
# stay_558 3
# stay_559 4
# sat
# 560 40
# Ulimate Cost 560 2174
# Num_timeslot 10 Optimal_cost 40
# schedule_560 3
# schedule_561 3
# schedule_562 3
# schedule_563 3
# schedule_564 3
# schedule_565 3
# schedule_566 3
# schedule_567 3
# schedule_568 3
# schedule_569 3
# stay_560 5
# stay_561 6
# stay_562 7
# stay_563 8
# stay_564 9
# stay_565 10
# stay_566 11
# stay_567 12
# stay_568 13
# stay_569 14
# sat
# 570 40
# Ulimate Cost 570 2214
# Num_timeslot 10 Optimal_cost 40
# schedule_570 3
# schedule_571 3
# schedule_572 3
# schedule_573 3
# schedule_574 3
# schedule_575 3
# schedule_576 3
# schedule_577 3
# schedule_578 3
# schedule_579 3
# stay_570 15
# stay_571 16
# stay_572 17
# stay_573 18
# stay_574 19
# stay_575 20
# stay_576 21
# stay_577 22
# stay_578 23
# stay_579 24
# sat
# 580 39
# Ulimate Cost 580 2253
# Num_timeslot 10 Optimal_cost 39
# schedule_580 3
# schedule_581 3
# schedule_582 4
# schedule_583 3
# schedule_584 3
# schedule_585 3
# schedule_586 3
# schedule_587 3
# schedule_588 3
# schedule_589 3
# stay_580 25
# stay_581 26
# stay_582 1
# stay_583 1
# stay_584 2
# stay_585 3
# stay_586 4
# stay_587 5
# stay_588 6
# stay_589 7
# sat
# 590 40
# Ulimate Cost 590 2293
# Num_timeslot 10 Optimal_cost 40
# schedule_590 3
# schedule_591 3
# schedule_592 3
# schedule_593 3
# schedule_594 3
# schedule_595 3
# schedule_596 3
# schedule_597 3
# schedule_598 3
# schedule_599 3
# stay_590 8
# stay_591 9
# stay_592 10
# stay_593 11
# stay_594 12
# stay_595 13
# stay_596 14
# stay_597 15
# stay_598 16
# stay_599 17
# sat
# 600 40
# Ulimate Cost 600 2333
# Num_timeslot 10 Optimal_cost 40
# schedule_600 3
# schedule_601 3
# schedule_602 3
# schedule_603 3
# schedule_604 3
# schedule_605 3
# schedule_606 3
# schedule_607 3
# schedule_608 3
# schedule_609 3
# stay_600 18
# stay_601 19
# stay_602 20
# stay_603 21
# stay_604 22
# stay_605 23
# stay_606 24
# stay_607 25
# stay_608 26
# stay_609 27
# sat
# 610 39
# Ulimate Cost 610 2372
# Num_timeslot 10 Optimal_cost 39
# schedule_610 4
# schedule_611 3
# schedule_612 3
# schedule_613 3
# schedule_614 3
# schedule_615 3
# schedule_616 3
# schedule_617 3
# schedule_618 3
# schedule_619 3
# stay_610 1
# stay_611 1
# stay_612 2
# stay_613 3
# stay_614 4
# stay_615 5
# stay_616 6
# stay_617 7
# stay_618 8
# stay_619 9
# sat
# 620 40
# Ulimate Cost 620 2412
# Num_timeslot 10 Optimal_cost 40
# schedule_620 3
# schedule_621 3
# schedule_622 3
# schedule_623 3
# schedule_624 3
# schedule_625 3
# schedule_626 3
# schedule_627 3
# schedule_628 3
# schedule_629 3
# stay_620 10
# stay_621 11
# stay_622 12
# stay_623 13
# stay_624 14
# stay_625 15
# stay_626 16
# stay_627 17
# stay_628 18
# stay_629 19
# sat
# 630 40
# Ulimate Cost 630 2452
# Num_timeslot 10 Optimal_cost 40
# schedule_630 3
# schedule_631 3
# schedule_632 3
# schedule_633 3
# schedule_634 3
# schedule_635 3
# schedule_636 3
# schedule_637 3
# schedule_638 3
# schedule_639 3
# stay_630 20
# stay_631 21
# stay_632 22
# stay_633 23
# stay_634 24
# stay_635 25
# stay_636 26
# stay_637 27
# stay_638 28
# stay_639 29
# sat
# 640 39
# Ulimate Cost 640 2491
# Num_timeslot 10 Optimal_cost 39
# schedule_640 3
# schedule_641 3
# schedule_642 4
# schedule_643 3
# schedule_644 3
# schedule_645 3
# schedule_646 3
# schedule_647 3
# schedule_648 3
# schedule_649 3
# stay_640 30
# stay_641 31
# stay_642 1
# stay_643 1
# stay_644 2
# stay_645 3
# stay_646 4
# stay_647 5
# stay_648 6
# stay_649 7
# sat
# 650 40
# Ulimate Cost 650 2531
# Num_timeslot 10 Optimal_cost 40
# schedule_650 3
# schedule_651 3
# schedule_652 3
# schedule_653 3
# schedule_654 3
# schedule_655 3
# schedule_656 3
# schedule_657 3
# schedule_658 3
# schedule_659 3
# stay_650 8
# stay_651 9
# stay_652 10
# stay_653 11
# stay_654 12
# stay_655 13
# stay_656 14
# stay_657 15
# stay_658 16
# stay_659 17
# sat
# 660 40
# Ulimate Cost 660 2571
# Num_timeslot 10 Optimal_cost 40
# schedule_660 3
# schedule_661 3
# schedule_662 3
# schedule_663 3
# schedule_664 3
# schedule_665 3
# schedule_666 3
# schedule_667 3
# schedule_668 3
# schedule_669 3
# stay_660 18
# stay_661 19
# stay_662 20
# stay_663 21
# stay_664 22
# stay_665 23
# stay_666 24
# stay_667 25
# stay_668 26
# stay_669 27
# sat
# 670 39
# Ulimate Cost 670 2610
# Num_timeslot 10 Optimal_cost 39
# schedule_670 3
# schedule_671 3
# schedule_672 3
# schedule_673 3
# schedule_674 4
# schedule_675 3
# schedule_676 3
# schedule_677 3
# schedule_678 3
# schedule_679 3
# stay_670 28
# stay_671 29
# stay_672 30
# stay_673 31
# stay_674 1
# stay_675 1
# stay_676 2
# stay_677 3
# stay_678 4
# stay_679 5
# sat
# 680 40
# Ulimate Cost 680 2650
# Num_timeslot 10 Optimal_cost 40
# schedule_680 3
# schedule_681 3
# schedule_682 3
# schedule_683 3
# schedule_684 3
# schedule_685 3
# schedule_686 3
# schedule_687 3
# schedule_688 3
# schedule_689 3
# stay_680 6
# stay_681 7
# stay_682 8
# stay_683 9
# stay_684 10
# stay_685 11
# stay_686 12
# stay_687 13
# stay_688 14
# stay_689 15
# sat
# 690 40
# Ulimate Cost 690 2690
# Num_timeslot 10 Optimal_cost 40
# schedule_690 3
# schedule_691 3
# schedule_692 3
# schedule_693 3
# schedule_694 3
# schedule_695 3
# schedule_696 3
# schedule_697 3
# schedule_698 3
# schedule_699 3
# stay_690 16
# stay_691 17
# stay_692 18
# stay_693 19
# stay_694 20
# stay_695 21
# stay_696 22
# stay_697 23
# stay_698 24
# stay_699 25
# sat
# 700 39
# Ulimate Cost 700 2729
# Num_timeslot 10 Optimal_cost 39
# schedule_700 3
# schedule_701 4
# schedule_702 3
# schedule_703 3
# schedule_704 3
# schedule_705 3
# schedule_706 3
# schedule_707 3
# schedule_708 3
# schedule_709 3
# stay_700 26
# stay_701 1
# stay_702 1
# stay_703 2
# stay_704 3
# stay_705 4
# stay_706 5
# stay_707 6
# stay_708 7
# stay_709 8
# sat
# 710 40
# Ulimate Cost 710 2769
# Num_timeslot 10 Optimal_cost 40
# schedule_710 3
# schedule_711 3
# schedule_712 3
# schedule_713 3
# schedule_714 3
# schedule_715 3
# schedule_716 3
# schedule_717 3
# schedule_718 3
# schedule_719 3
# stay_710 9
# stay_711 10
# stay_712 11
# stay_713 12
# stay_714 13
# stay_715 14
# stay_716 15
# stay_717 16
# stay_718 17
# stay_719 18
# sat
# 720 39
# Ulimate Cost 720 2808
# Num_timeslot 10 Optimal_cost 39
# schedule_720 3
# schedule_721 3
# schedule_722 3
# schedule_723 3
# schedule_724 3
# schedule_725 3
# schedule_726 3
# schedule_727 3
# schedule_728 4
# schedule_729 3
# stay_720 19
# stay_721 20
# stay_722 21
# stay_723 22
# stay_724 23
# stay_725 24
# stay_726 25
# stay_727 26
# stay_728 1
# stay_729 1
# sat
# 730 40
# Ulimate Cost 730 2848
# Num_timeslot 10 Optimal_cost 40
# schedule_730 3
# schedule_731 3
# schedule_732 3
# schedule_733 3
# schedule_734 3
# schedule_735 3
# schedule_736 3
# schedule_737 3
# schedule_738 3
# schedule_739 3
# stay_730 2
# stay_731 3
# stay_732 4
# stay_733 5
# stay_734 6
# stay_735 7
# stay_736 8
# stay_737 9
# stay_738 10
# stay_739 11
# sat
# 740 40
# Ulimate Cost 740 2888
# Num_timeslot 10 Optimal_cost 40
# schedule_740 3
# schedule_741 3
# schedule_742 3
# schedule_743 3
# schedule_744 3
# schedule_745 3
# schedule_746 3
# schedule_747 3
# schedule_748 3
# schedule_749 3
# stay_740 12
# stay_741 13
# stay_742 14
# stay_743 15
# stay_744 16
# stay_745 17
# stay_746 18
# stay_747 19
# stay_748 20
# stay_749 21
# sat
# 750 38
# Ulimate Cost 750 2926
# Num_timeslot 10 Optimal_cost 38
# schedule_750 4
# schedule_751 4
# schedule_752 3
# schedule_753 3
# schedule_754 3
# schedule_755 3
# schedule_756 3
# schedule_757 3
# schedule_758 3
# schedule_759 3
# stay_750 1
# stay_751 2
# stay_752 1
# stay_753 2
# stay_754 3
# stay_755 4
# stay_756 5
# stay_757 6
# stay_758 7
# stay_759 8
# sat
# 760 39
# Ulimate Cost 760 2965
# Num_timeslot 10 Optimal_cost 39
# schedule_760 3
# schedule_761 3
# schedule_762 3
# schedule_763 3
# schedule_764 3
# schedule_765 3
# schedule_766 3
# schedule_767 3
# schedule_768 3
# schedule_769 4
# stay_760 9
# stay_761 10
# stay_762 11
# stay_763 12
# stay_764 13
# stay_765 14
# stay_766 15
# stay_767 16
# stay_768 17
# stay_769 1
# sat
# 770 39
# Ulimate Cost 770 3004
# Num_timeslot 10 Optimal_cost 39
# schedule_770 4
# schedule_771 3
# schedule_772 3
# schedule_773 3
# schedule_774 3
# schedule_775 3
# schedule_776 3
# schedule_777 3
# schedule_778 3
# schedule_779 3
# stay_770 2
# stay_771 1
# stay_772 2
# stay_773 3
# stay_774 4
# stay_775 5
# stay_776 6
# stay_777 7
# stay_778 8
# stay_779 9
# sat
# 780 38
# Ulimate Cost 780 3042
# Num_timeslot 10 Optimal_cost 38
# schedule_780 3
# schedule_781 4
# schedule_782 4
# schedule_783 3
# schedule_784 3
# schedule_785 3
# schedule_786 3
# schedule_787 3
# schedule_788 3
# schedule_789 3
# stay_780 10
# stay_781 1
# stay_782 2
# stay_783 1
# stay_784 2
# stay_785 3
# stay_786 4
# stay_787 5
# stay_788 6
# stay_789 7
# sat
# 790 38
# Ulimate Cost 790 3080
# Num_timeslot 10 Optimal_cost 38
# schedule_790 3
# schedule_791 3
# schedule_792 3
# schedule_793 3
# schedule_794 4
# schedule_795 4
# schedule_796 3
# schedule_797 3
# schedule_798 3
# schedule_799 3
# stay_790 8
# stay_791 9
# stay_792 10
# stay_793 11
# stay_794 1
# stay_795 2
# stay_796 1
# stay_797 2
# stay_798 3
# stay_799 4
# sat
# 800 38
# Ulimate Cost 800 3118
# Num_timeslot 10 Optimal_cost 38
# schedule_800 3
# schedule_801 3
# schedule_802 4
# schedule_803 4
# schedule_804 3
# schedule_805 3
# schedule_806 3
# schedule_807 3
# schedule_808 3
# schedule_809 3
# stay_800 5
# stay_801 6
# stay_802 1
# stay_803 2
# stay_804 1
# stay_805 2
# stay_806 3
# stay_807 4
# stay_808 5
# stay_809 6
# sat
# 810 36
# Ulimate Cost 810 3154
# Num_timeslot 10 Optimal_cost 36
# schedule_810 4
# schedule_811 4
# schedule_812 3
# schedule_813 3
# schedule_814 3
# schedule_815 3
# schedule_816 4
# schedule_817 4
# schedule_818 3
# schedule_819 3
# stay_810 1
# stay_811 2
# stay_812 1
# stay_813 2
# stay_814 3
# stay_815 4
# stay_816 1
# stay_817 2
# stay_818 1
# stay_819 2
# sat
# 820 36
# Ulimate Cost 820 3190
# Num_timeslot 10 Optimal_cost 36
# schedule_820 3
# schedule_821 3
# schedule_822 4
# schedule_823 4
# schedule_824 3
# schedule_825 3
# schedule_826 4
# schedule_827 4
# schedule_828 3
# schedule_829 3
# stay_820 3
# stay_821 4
# stay_822 1
# stay_823 2
# stay_824 1
# stay_825 2
# stay_826 1
# stay_827 2
# stay_828 1
# stay_829 2
# sat
# 830 28
# Ulimate Cost 830 3218
# Num_timeslot 10 Optimal_cost 28
# schedule_830 4
# schedule_831 4
# schedule_832 4
# schedule_833 3
# schedule_834 4
# schedule_835 4
# schedule_836 4
# schedule_837 0
# schedule_838 4
# schedule_839 4
# stay_830 1
# stay_831 2
# stay_832 3
# stay_833 1
# stay_834 1
# stay_835 2
# stay_836 3
# stay_837 1
# stay_838 1
# stay_839 2
# sat
# 840 20
# Ulimate Cost 840 3238
# Num_timeslot 10 Optimal_cost 20
# schedule_840 2
# schedule_841 2
# schedule_842 2
# schedule_843 2
# schedule_844 2
# schedule_845 2
# schedule_846 2
# schedule_847 2
# schedule_848 2
# schedule_849 2
# stay_840 1
# stay_841 2
# stay_842 3
# stay_843 4
# stay_844 5
# stay_845 6
# stay_846 7
# stay_847 8
# stay_848 9
# stay_849 10
# sat
# 850 20
# Ulimate Cost 850 3258
# Num_timeslot 10 Optimal_cost 20
# schedule_850 2
# schedule_851 2
# schedule_852 2
# schedule_853 2
# schedule_854 2
# schedule_855 2
# schedule_856 2
# schedule_857 2
# schedule_858 2
# schedule_859 2
# stay_850 11
# stay_851 12
# stay_852 13
# stay_853 14
# stay_854 15
# stay_855 16
# stay_856 17
# stay_857 18
# stay_858 19
# stay_859 20
# sat
# 860 20
# Ulimate Cost 860 3278
# Num_timeslot 10 Optimal_cost 20
# schedule_860 2
# schedule_861 2
# schedule_862 2
# schedule_863 2
# schedule_864 2
# schedule_865 2
# schedule_866 2
# schedule_867 2
# schedule_868 2
# schedule_869 2
# stay_860 21
# stay_861 22
# stay_862 23
# stay_863 24
# stay_864 25
# stay_865 26
# stay_866 27
# stay_867 28
# stay_868 29
# stay_869 30
# sat
# 870 20
# Ulimate Cost 870 3298
# Num_timeslot 10 Optimal_cost 20
# schedule_870 2
# schedule_871 2
# schedule_872 2
# schedule_873 2
# schedule_874 2
# schedule_875 2
# schedule_876 2
# schedule_877 2
# schedule_878 2
# schedule_879 2
# stay_870 31
# stay_871 32
# stay_872 33
# stay_873 34
# stay_874 35
# stay_875 36
# stay_876 37
# stay_877 38
# stay_878 39
# stay_879 40
# sat
# 880 20
# Ulimate Cost 880 3318
# Num_timeslot 10 Optimal_cost 20
# schedule_880 2
# schedule_881 2
# schedule_882 2
# schedule_883 2
# schedule_884 2
# schedule_885 2
# schedule_886 2
# schedule_887 2
# schedule_888 2
# schedule_889 2
# stay_880 41
# stay_881 42
# stay_882 43
# stay_883 44
# stay_884 45
# stay_885 46
# stay_886 47
# stay_887 48
# stay_888 49
# stay_889 50
# sat
# 890 20
# Ulimate Cost 890 3338
# Num_timeslot 10 Optimal_cost 20
# schedule_890 2
# schedule_891 2
# schedule_892 2
# schedule_893 2
# schedule_894 2
# schedule_895 2
# schedule_896 2
# schedule_897 2
# schedule_898 2
# schedule_899 2
# stay_890 51
# stay_891 52
# stay_892 53
# stay_893 54
# stay_894 55
# stay_895 56
# stay_896 57
# stay_897 58
# stay_898 59
# stay_899 60
# sat
# 900 20
# Ulimate Cost 900 3358
# Num_timeslot 10 Optimal_cost 20
# schedule_900 2
# schedule_901 2
# schedule_902 2
# schedule_903 2
# schedule_904 2
# schedule_905 2
# schedule_906 2
# schedule_907 2
# schedule_908 2
# schedule_909 2
# stay_900 61
# stay_901 62
# stay_902 63
# stay_903 64
# stay_904 65
# stay_905 66
# stay_906 67
# stay_907 68
# stay_908 69
# stay_909 70
# sat
# 910 22
# Ulimate Cost 910 3380
# Num_timeslot 10 Optimal_cost 22
# schedule_910 2
# schedule_911 2
# schedule_912 2
# schedule_913 2
# schedule_914 2
# schedule_915 2
# schedule_916 2
# schedule_917 0
# schedule_918 3
# schedule_919 3
# stay_910 71
# stay_911 72
# stay_912 73
# stay_913 74
# stay_914 75
# stay_915 76
# stay_916 77
# stay_917 1
# stay_918 1
# stay_919 2
# sat
# 920 40
# Ulimate Cost 920 3420
# Num_timeslot 10 Optimal_cost 40
# schedule_920 3
# schedule_921 3
# schedule_922 3
# schedule_923 3
# schedule_924 3
# schedule_925 3
# schedule_926 3
# schedule_927 3
# schedule_928 3
# schedule_929 3
# stay_920 3
# stay_921 4
# stay_922 5
# stay_923 6
# stay_924 7
# stay_925 8
# stay_926 9
# stay_927 10
# stay_928 11
# stay_929 12
# sat
# 930 40
# Ulimate Cost 930 3460
# Num_timeslot 10 Optimal_cost 40
# schedule_930 3
# schedule_931 3
# schedule_932 3
# schedule_933 3
# schedule_934 3
# schedule_935 3
# schedule_936 3
# schedule_937 3
# schedule_938 3
# schedule_939 3
# stay_930 13
# stay_931 14
# stay_932 15
# stay_933 16
# stay_934 17
# stay_935 18
# stay_936 19
# stay_937 20
# stay_938 21
# stay_939 22
# sat
# 940 40
# Ulimate Cost 940 3500
# Num_timeslot 10 Optimal_cost 40
# schedule_940 3
# schedule_941 3
# schedule_942 3
# schedule_943 3
# schedule_944 3
# schedule_945 3
# schedule_946 3
# schedule_947 3
# schedule_948 3
# schedule_949 3
# stay_940 23
# stay_941 24
# stay_942 25
# stay_943 26
# stay_944 27
# stay_945 28
# stay_946 29
# stay_947 30
# stay_948 31
# stay_949 32
# sat
# 950 40
# Ulimate Cost 950 3540
# Num_timeslot 10 Optimal_cost 40
# schedule_950 3
# schedule_951 3
# schedule_952 3
# schedule_953 3
# schedule_954 3
# schedule_955 3
# schedule_956 3
# schedule_957 3
# schedule_958 3
# schedule_959 3
# stay_950 33
# stay_951 34
# stay_952 35
# stay_953 36
# stay_954 37
# stay_955 38
# stay_956 39
# stay_957 40
# stay_958 41
# stay_959 42
# sat
# 960 40
# Ulimate Cost 960 3580
# Num_timeslot 10 Optimal_cost 40
# schedule_960 3
# schedule_961 3
# schedule_962 3
# schedule_963 3
# schedule_964 3
# schedule_965 3
# schedule_966 3
# schedule_967 3
# schedule_968 3
# schedule_969 3
# stay_960 43
# stay_961 44
# stay_962 45
# stay_963 46
# stay_964 47
# stay_965 48
# stay_966 49
# stay_967 50
# stay_968 51
# stay_969 52
# sat
# 970 40
# Ulimate Cost 970 3620
# Num_timeslot 10 Optimal_cost 40
# schedule_970 3
# schedule_971 3
# schedule_972 3
# schedule_973 3
# schedule_974 3
# schedule_975 3
# schedule_976 3
# schedule_977 3
# schedule_978 3
# schedule_979 3
# stay_970 53
# stay_971 54
# stay_972 55
# stay_973 56
# stay_974 57
# stay_975 58
# stay_976 59
# stay_977 60
# stay_978 61
# stay_979 62
# sat
# 980 40
# Ulimate Cost 980 3660
# Num_timeslot 10 Optimal_cost 40
# schedule_980 3
# schedule_981 3
# schedule_982 3
# schedule_983 3
# schedule_984 3
# schedule_985 3
# schedule_986 3
# schedule_987 3
# schedule_988 3
# schedule_989 3
# stay_980 63
# stay_981 64
# stay_982 65
# stay_983 66
# stay_984 67
# stay_985 68
# stay_986 69
# stay_987 70
# stay_988 71
# stay_989 72

# %%
linearized_shchecker_adm
